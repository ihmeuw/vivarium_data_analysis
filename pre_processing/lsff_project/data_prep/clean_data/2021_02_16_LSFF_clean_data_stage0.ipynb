# %%
import pandas as pd, numpy as np

# %% [markdown]
# # LSFF: basic data cleaning

# %% [markdown]
# IN: extraction sheet + vehicle-nutrient, country-vehicle dicts

# %% [markdown]
# OUT: cleaned extraction sheet. values renamed, dropped all illegal location-vehicle-val-nutrient combos

# %%
## load targets
import pickle
inputs_dir = '/ihme/homes/beatrixh/vivarium_data_analysis/pre_processing/lsff_project/data_prep/inputs/'

with open(inputs_dir + 'lsff_vehicle_nutrient_pairs.pickle', 'rb') as handle:
    vehicle_nutrient_map = pickle.load(handle)
    
with open(inputs_dir + 'lsff_country_vehicle_pairs.pickle', 'rb') as handle:
    country_vehicle_map = pickle.load(handle)

countries = [i for i in country_vehicle_map.keys() if type(i)==str]

path = inputs_dir + 'extraction_sheet_lsff_02_16_2021.csv'
df = pd.read_csv(path, encoding = 'utf-8')

# %%
path = inputs_dir + 'extraction_sheet_lsff_02_16_2021.csv'
df = pd.read_csv(path, encoding = 'utf-8')

# %%
check_cols = ['location_id','location_name','vehicle','value_description','nutrient','value_mean','value_025_percentile',
       'value_975_percentile','notes']

# %%
# format vars
df.location_id = df.location_id.fillna(-1).astype(int)
df.location_name = df.location_name.astype(str)
df.vehicle = df.vehicle.astype(str)
df.value_description = df.value_description.astype(str)

df.value_mean = df.value_mean.mask(df.value_mean.isin(['na',np.nan,-1,'unknown']), np.nan).astype(float)
df.value_025_percentile = df.value_025_percentile.mask(df.value_025_percentile.isin(['na',np.nan,-1,'unknown']), np.nan).astype(float)
df.value_975_percentile = df.value_975_percentile.mask(df.value_975_percentile.isin(['na',np.nan,-1,'unknown']), np.nan).astype(float)

# %%
#drop all NaN-only rows
df = df.loc[~((df.value_mean.isna())&(df.value_025_percentile.isna())&(df.value_975_percentile.isna()))]

# %%
#locations for which need tofill in loc_ids
df[df.location_id==-1].location_name.unique()
# Out:
# array(['China', 'Egypt', 'South Africa', 'Nepal'], dtype=object)

# %%
#looks like we'll need to estimate mean here
df.loc[df.value_mean.isna(),check_cols]
# Out:
#      location_id location_name vehicle  \
# 262          207         Ghana    rice
# 501          214       Nigeria    rice
#
#                                     value_description nutrient  value_mean  \
# 262  percent of vehicle that is industrially produced       na         NaN
# 501  percent of vehicle that is industrially produced       na         NaN
#
#      value_025_percentile  value_975_percentile  \
# 262                  11.0                  23.0
# 501                  12.0                  24.0
#
#                                              notes
# 262  % industrially milled, only a range was given
# 501  % industrially milled, only a range was given

# %% [markdown]
# ## location_name

# %%
df.location_name.unique()
# Out:
# array(['India', 'Bangladesh', 'Pakistan', 'Burkina Faso', 'Nigeria',
#        "Côte d'Ivoire", 'Cameroon', 'Uganda',
#        'United Republic of Tanzania', 'Ethiopia', 'China',
#        'Democratic Republic of the Congo', 'Egypt', 'Philippines',
#        'Ghana', 'Niger', 'Sudan', 'Yemen', 'Viet Nam', 'Angola', 'Kenya',
#        'Indonesia', 'Madagascar', 'Mozambique', 'Nepal', 'Myanmar',
#        'South Africa', "CÃ´te d'Ivoire"], dtype=object)

# %%
relabel_location_name = {'India': 'India',
 'Bangladesh': 'Bangladesh',
 'Cameroon': 'Cameroon',
 'Nigeria': 'Nigeria',
 'Pakistan': 'Pakistan',
 'Burkina Faso': 'Burkina Faso',
 "CÃ´te d'Ivoire": "Côte d'Ivoire",
 "Côte d'Ivoire":"Côte d'Ivoire",
 'Uganda': 'Uganda',
 'United Republic of Tanzania': 'United Republic of Tanzania',
 'Ethiopia': 'Ethiopia',
 'China': 'China',
 'Indonesia': 'Indonesia',
 'Democratic Republic of the Congo': 'Democratic Republic of the Congo',
 'Kenya': 'Kenya',
 'Egypt': 'Egypt',
 'Niger': 'Niger',
 'Philippines': 'Philippines',
 'Ghana': 'Ghana',
 'Afghanistan': 'Afghanistan',
 'Viet Nam': 'Vietnam', ##TODO: fix this so that it's Viet Nam
 'Yemen': 'Yemen',
 'Sudan': 'Sudan',
 'Angola': 'Angola',
 'Iraq':'Iraq',
 'Madagascar': 'Madagascar',
 'Mozambique': 'Mozambique',
 'Nepal': 'Nepal',
 'Myanmar': 'Myanmar',
 'South Africa': 'South Africa'}

# %%
df.location_name = df.location_name.map(relabel_location_name)

# %%
## exclude countries the gates foundation had us drop (politically unstable or low rates of maternal and child anemia)
excluded_countries = ['Afghanistan','Yemen','Philippines','Iraq']
df = df[~df.location_name.isin(excluded_countries)]

# %%
## clean country names
assert df.location_name.nunique()==25, "wrong number of countries"

# %%
df.location_name.unique()
# Out:
# array(['India', 'Bangladesh', 'Pakistan', 'Burkina Faso', 'Nigeria',
#        "Côte d'Ivoire", 'Cameroon', 'Uganda',
#        'United Republic of Tanzania', 'Ethiopia', 'China',
#        'Democratic Republic of the Congo', 'Egypt', 'Ghana', 'Niger',
#        'Sudan', 'Vietnam', 'Angola', 'Kenya', 'Indonesia', 'Madagascar',
#        'Mozambique', 'Nepal', 'Myanmar', 'South Africa'], dtype=object)

# %%
for i in df.location_name.unique():
    if i not in countries:
        print(i)
    assert(i in countries)

# %% [markdown]
# ## vehicle

# %%
##this one looks fine
df.vehicle.unique()
# Out:
# array(['oil', 'wheat flour', 'salt', 'rice', 'maize flour', 'bouillon'],
#       dtype=object)

# %% [markdown]
# ## nutrient

# %%
nutrient_map = {'vitamin a': 'vitamin a',
 'na': 'na',
 'iron': 'iron',
 'folic acid, folate, b9': 'folic acid',
 'b12': 'vitamin b12',
 'iodine': 'iodine',
 'b1, thiamine': 'vitamin b1',
 'zinc': 'zinc',
 'd, ergocalciferol-D2, cholecalciferol-D3, alfacalcidol': 'vitamin d',
 'b2, riboflavin': 'vitamin b2',
 'b3, niacin': 'vitamin b3',
 'b6, pyridoxine': 'vitamin b6'}

# %%
df.nutrient = df.nutrient.map(nutrient_map)

# %%
# fill nans
df['nutrient'] = df['nutrient'].fillna('na')

# %% [markdown]
# ## value_description

# %%
df.value_description.unique()
# Out:
# array(['percent of population eating fortified vehicle',
#        'percent of population eating industrially produced vehicle',
#        'percent of population eating vehicle',
#        'percent of vehicle that is industrially produced',
#        'percent of vehicle that is fortified',
#        'percent of marketshare of fortified products'], dtype=object)

# %% [markdown]
# ## eliminate country-vehicle and vehicle-nutrient pairs we're uninterested in

# %%
country_vehicle_pairs = pd.DataFrame([(i,j) for i in countries for j in country_vehicle_map[i]], columns = ['location_name','vehicle'])

# %%
vehicles = list(vehicle_nutrient_map.keys())
vehicle_nutrient_pairs = pd.DataFrame([(i,j) for i in vehicles for j in vehicle_nutrient_map[i]], columns = ['vehicle','nutrient'])
vehicle_nutrient_pairs = pd.concat([vehicle_nutrient_pairs, pd.DataFrame([(i,'na') for i in vehicles], columns = ['vehicle','nutrient'])])

# %%
# check what we're removing
test = df.merge(vehicle_nutrient_pairs, on = ['vehicle','nutrient'], how = 'right')
[(i,j) for (i,j) in zip(df.vehicle,df.nutrient) if (i,j) not in zip(test.vehicle,test.nutrient)]
# Out:
# [('salt', 'iodine'),
#  ('salt', 'iodine'),
#  ('salt', 'iodine'),
#  ('salt', 'iodine'),
#  ('salt', 'iodine'),
#  ('salt', 'iodine'),
#  ('rice', 'vitamin a'),
#  ('salt', 'iodine')]

# %%
df = df.merge(country_vehicle_pairs, on = ['location_name','vehicle'], how = 'right') #should this be inner?

# %%
df = df.merge(vehicle_nutrient_pairs, on = ['vehicle','nutrient'], how = 'right')

# %%
#drop all NaN-only rows
df = df.loc[~((df.value_mean.isna())&(df.value_025_percentile.isna())&(df.value_975_percentile.isna()))]

# %% [markdown]
# ## clean illegal value-nutrient combos

# %%
nutrient_irrelevant_vds = ['percent of population eating industrially produced vehicle',
       'percent of population eating vehicle',
       'percent of vehicle that is industrially produced',
       'percent of marketshare of fortified products']

nutrient_relevant_vds = ['percent of population eating fortified vehicle',
       'percent of vehicle that is fortified',
       'percent of marketshare of fortified products']

# %%
df.nutrient.unique()
# Out:
# array(['vitamin a', 'na', 'vitamin d', 'iron', 'folic acid',
#        'vitamin b12', 'zinc', 'vitamin b1'], dtype=object)

# %%
df.loc[(df.value_description.isin(nutrient_irrelevant_vds))&(df.nutrient!='na'),check_cols]
# Out:
#     location_id  location_name vehicle  \
# 1         161.0     Bangladesh     oil
# 3         161.0     Bangladesh     oil
# 17        205.0  Côte d'Ivoire     oil
#
#                                     value_description   nutrient  value_mean  \
# 1    percent of vehicle that is industrially produced  vitamin a        52.0
# 3   percent of population eating industrially prod...  vitamin a        87.5
# 17       percent of marketshare of fortified products  vitamin a        89.0
#
#     value_025_percentile  value_975_percentile           notes
# 1                    NaN                   NaN  no uncertainty
# 3                    NaN                   NaN  no uncertainty
# 17                   NaN                   NaN             NaN

# %%
# relabel nutrients for rows for which nutrient doesn't apply
df.loc[(df.value_description.isin(nutrient_irrelevant_vds))&(df.nutrient!='na'),'nutrient'] = 'na'

# %%
# these need to be re extracted; for now we'll drop them
df.loc[(df.value_description.isin(nutrient_relevant_vds)) & (df.nutrient=='na'),check_cols + ['user']].sort_values(['user','location_name'])
# Out:
#      location_id  location_name      vehicle  \
# 509        202.0       Cameroon  maize flour
# 17         205.0  Côte d'Ivoire          oil
#
#                                 value_description nutrient  value_mean  \
# 509          percent of vehicle that is fortified       na        50.0
# 17   percent of marketshare of fortified products       na        89.0
#
#      value_025_percentile  value_975_percentile  \
# 509                   NaN                   NaN
# 17                    NaN                   NaN
#
#                                                  notes     user
# 509  Unknown what this measure of fortified maize f...  paulina
# 17                                                 NaN  paulina

# %%
# drop rows that need nutrient filled in
df = df.loc[~((df.value_description.isin(nutrient_relevant_vds)) & (df.nutrient=='na')),]

# %%
# format vars
df.location_id = df.location_id.fillna(-1).astype(int)
df.location_name = df.location_name.astype(str)
df.vehicle = df.vehicle.astype(str)
df.value_description = df.value_description.astype(str)

df.value_mean = df.value_mean.mask(df.value_mean.isin(['na',np.nan,-1,'unknown']), np.nan).astype(float)
df.value_025_percentile = df.value_025_percentile.mask(df.value_025_percentile.isin(['na',np.nan,-1,'unknown']), np.nan).astype(float)
df.value_975_percentile = df.value_975_percentile.mask(df.value_975_percentile.isin(['na',np.nan,-1,'unknown']), np.nan).astype(float)

# %%
df.head()
# Out:
#    location_id location_name subnational_name subnational_location_id  \
# 0          163         India        Rajasthan                     NaN
# 1          161    Bangladesh               na                     NaN
# 2          161    Bangladesh               na                     NaN
# 3          161    Bangladesh               na                     NaN
# 4          165      Pakistan      Balochistan                     NaN
#
#   urbanicity vehicle   nutrient nutrient_compound nutrient_mass_ppm  \
# 0        NaN     oil  vitamin a           unknown               7.5
# 1        NaN     oil         na                na              22.5
# 2        NaN     oil  vitamin a                na              22.5
# 3        NaN     oil         na                na                na
# 4    unknown     oil  vitamin a                na               NaN
#
#   fortification_standards  ...  \
# 0               voluntary  ...
# 1               mandatory  ...
# 2               mandatory  ...
# 3               mandatory  ...
# 4               mandatory  ...
#
#                                      source_citation  \
# 0  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 1                                               GFDx
# 2                                               GFDx
# 3  Raghavan R, Aaron GJ, Nahar B, et al. Househol...
# 4                                                NaN
#
#                                          source_link source_year  \
# 0              https://doi.org/10.3945/jn.116.245753        2017
# 1  https://fortificationdata.org/country-fortific...        2018
# 2  https://fortificationdata.org/country-fortific...        2017
# 3  https://journals.plos.org/plosone/article?id=1...        2015
# 4  https://www.gainhealth.org/sites/default/files...         NaN
#
#                 source_type  source_additional  \
# 0                       NaN                NaN
# 1                       NaN                NaN
# 2                       NaN                NaN
# 3                       NaN                NaN
# 4  Survey - cross-sectional                NaN
#
#                                                notes       user date_recorded  \
# 0                                                NaN  nathaniel    10/30/2020
# 1                                     no uncertainty       yaqi    11/18/2020
# 2                                     no uncertainty       yaqi    11/18/2020
# 3                                     no uncertainty       yaqi    11/18/2020
# 4  Consumption of the fortified food vehicle was ...      rohit    11/24/2020
#
#   Validated Unnamed: 27
# 0       Yes         NaN
# 1       NaN         NaN
# 2       NaN         NaN
# 3       NaN         NaN
# 4       NaN         NaN
#
# [5 rows x 28 columns]

# %%
df[df.location_id==-1]
# Out:
#      location_id location_name subnational_name subnational_location_id  \
# 145           -1         Nepal               na                     NaN
# 146           -1         Nepal               na                     NaN
# 147           -1         Nepal               na                     NaN
# 166           -1         China               na                     NaN
# 248           -1         China               na                     NaN
# 249           -1         China               na                     NaN
# 252           -1         Egypt               na                     NaN
# 253           -1         Egypt               na                     NaN
# 295           -1         Nepal               na                     NaN
# 296           -1         Nepal               na                     NaN
# 297           -1         Nepal               na                     NaN
# 298           -1         Nepal               na                     NaN
# 299           -1         Nepal               na                     NaN
# 300           -1         Nepal               na                     NaN
# 337           -1         China               na                     NaN
# 387           -1         China               na                     NaN
# 416           -1         China               na                     NaN
# 442           -1         China               na                     NaN
# 546           -1  South Africa               na                     NaN
# 553           -1         Egypt               na                     NaN
#
#      urbanicity      vehicle    nutrient nutrient_compound nutrient_mass_ppm  \
# 145  mixed/both          oil          na                na                na
# 146       urban          oil          na                na                na
# 147       rural          oil          na                na                na
# 166         NaN  wheat flour        iron               NaN               NaN
# 248         NaN  wheat flour          na                na               NaN
# 249     unknown  wheat flour          na                na               NaN
# 252         NaN  wheat flour          na                na               NaN
# 253         NaN  wheat flour          na                na                na
# 295  mixed/both  wheat flour          na                na                na
# 296       urban  wheat flour          na                na                na
# 297       rural  wheat flour          na                na                na
# 298  mixed/both  wheat flour          na                na                na
# 299       urban  wheat flour          na                na                na
# 300       rural  wheat flour          na                na                na
# 337         NaN  wheat flour  folic acid                na               NaN
# 387         NaN  wheat flour   vitamin a                na               NaN
# 416         NaN  wheat flour        zinc                na               NaN
# 442         NaN  wheat flour  vitamin b1                na               NaN
# 546         NaN  maize flour          na                na                na
# 553         NaN  maize flour          na                na                na
#
#     fortification_standards  ... source_citation  \
# 145                      na  ...            GHDx
# 146                      na  ...            GHDx
# 147                      na  ...            GHDx
# 166               voluntary  ...            GFDx
# 248               voluntary  ...             NaN
# 249               voluntary  ...             NaN
# 252               mandatory  ...             NaN
# 253                      na  ...            GFDx
# 295                      na  ...            GHDx
# 296                      na  ...            GHDx
# 297                      na  ...            GHDx
# 298                      na  ...            GHDx
# 299                      na  ...            GHDx
# 300                      na  ...            GHDx
# 337               voluntary  ...            GFDx
# 387               voluntary  ...            GFDx
# 416               voluntary  ...            GFDx
# 442               voluntary  ...            GFDx
# 546                      na  ...            GFDx
# 553                      na  ...            GFDx
#
#                                            source_link source_year  \
# 145  http://internal-ghdx.healthdata.org/record/nep...        2016
# 146  http://internal-ghdx.healthdata.org/record/nep...        2016
# 147  http://internal-ghdx.healthdata.org/record/nep...        2016
# 166  https://fortificationdata.org/country-fortific...         NaN
# 248       https://www.mdpi.com/2072-6643/11/7/1594/htm        2012
# 249  https://fortificationdata.org/chart-quantity-a...         NaN
# 252       https://www.mdpi.com/2072-6643/11/7/1594/htm         NaN
# 253  https://fortificationdata.org/country-fortific...        2017
# 295  http://internal-ghdx.healthdata.org/record/nep...        2016
# 296  http://internal-ghdx.healthdata.org/record/nep...        2016
# 297  http://internal-ghdx.healthdata.org/record/nep...        2016
# 298  http://internal-ghdx.healthdata.org/record/nep...        2016
# 299  http://internal-ghdx.healthdata.org/record/nep...        2016
# 300  http://internal-ghdx.healthdata.org/record/nep...        2016
# 337  https://fortificationdata.org/country-fortific...         NaN
# 387  https://fortificationdata.org/country-fortific...         NaN
# 416  https://fortificationdata.org/country-fortific...         NaN
# 442  https://fortificationdata.org/country-fortific...         NaN
# 546  https://fortificationdata.org/country-fortific...        2017
# 553  https://fortificationdata.org/country-fortific...        2017
#
#                   source_type  source_additional  \
# 145  Survey - cross-sectional                NaN
# 146  Survey - cross-sectional                NaN
# 147  Survey - cross-sectional                NaN
# 166                       NaN                NaN
# 248  Survey - cross-sectional                NaN
# 249  Survey - cross-sectional                NaN
# 252  Survey - cross-sectional                NaN
# 253                       NaN                NaN
# 295  Survey - cross-sectional                NaN
# 296  Survey - cross-sectional                NaN
# 297  Survey - cross-sectional                NaN
# 298  Survey - cross-sectional                NaN
# 299  Survey - cross-sectional                NaN
# 300  Survey - cross-sectional                NaN
# 337                       NaN                NaN
# 387                       NaN                NaN
# 416                       NaN                NaN
# 442                       NaN                NaN
# 546                       NaN                NaN
# 553                       NaN                NaN
#
#                                                  notes     user date_recorded  \
# 145  Reported Households Used Cooking Oil to Cook o...  paulina    12/09/2020
# 146  Reported Households Used Cooking Oil to Cook o...  paulina    12/09/2020
# 147  Reported Households Used Cooking Oil to Cook o...  paulina    12/09/2020
# 166                                                NaN  paulina    12/04/2020
# 248                                Data is in table S1    rohit    12/18/2020
# 249                                                NaN    rohit    12/10/2020
# 252  Data is in table S2 and they did not mention year    rohit    12/18/2020
# 253  Source for industrially processed: Magdy Sheha...  paulina    12/04/2020
# 295  Specifically Maida Wheat Flour Purchased and A...  paulina    12/09/2020
# 296  Specifically Maida Wheat Flour Purchased and A...  paulina    12/09/2020
# 297  Specifically Maida Wheat Flour Purchased and A...  paulina    12/09/2020
# 298  Specifically Atta Wheat Flour Purchased and Av...  paulina    12/09/2020
# 299  Specifically Atta Wheat Flour Purchased and Av...  paulina    12/09/2020
# 300  Specifically Atta Wheat Flour Purchased and Av...  paulina    12/09/2020
# 337                                                NaN  paulina    12/04/2020
# 387                                                NaN  paulina    12/04/2020
# 416                                                NaN  paulina    12/04/2020
# 442                                                NaN  paulina    12/04/2020
# 546  Source for industrially processed: Philip Rand...  paulina    12/04/2020
# 553  Source for industrially processed: Magdy Sheha...  paulina    12/04/2020
#
#     Validated Unnamed: 27
# 145       NaN         NaN
# 146       NaN         NaN
# 147       NaN         NaN
# 166       NaN         NaN
# 248       NaN         NaN
# 249       NaN         NaN
# 252       NaN         NaN
# 253       NaN         NaN
# 295       NaN         NaN
# 296       NaN         NaN
# 297       NaN         NaN
# 298       NaN         NaN
# 299       NaN         NaN
# 300       NaN         NaN
# 337       NaN         NaN
# 387       NaN         NaN
# 416       NaN         NaN
# 442       NaN         NaN
# 546       NaN         NaN
# 553       NaN         NaN
#
# [20 rows x 28 columns]

# %%
loc_ids_path = '/ihme/homes/beatrixh/notebooks/viv_rsc/data_prep/inputs/location_ids.csv'
loc_ids = pd.read_csv(loc_ids_path)
loc_ids.location_name = loc_ids.location_name.astype(str)

# %%
loc_ids[loc_ids.location_name=="Viet Nam"]
# Out:
#      location_id location_name
# 542           20      Viet Nam

# %%
ref = [str(i) for i in loc_ids.location_name]

# %%
df.loc[df.location_name=='Vietnam','location_name'] = 'Viet Nam' # FIX THIS AT THE ORIGIN

# %%
for loc in df.location_name.unique():
    if loc not in ref:
        print(loc)

# %%
df.head()
# Out:
#    location_id location_name subnational_name subnational_location_id  \
# 0          163         India        Rajasthan                     NaN
# 1          161    Bangladesh               na                     NaN
# 2          161    Bangladesh               na                     NaN
# 3          161    Bangladesh               na                     NaN
# 4          165      Pakistan      Balochistan                     NaN
#
#   urbanicity vehicle   nutrient nutrient_compound nutrient_mass_ppm  \
# 0        NaN     oil  vitamin a           unknown               7.5
# 1        NaN     oil         na                na              22.5
# 2        NaN     oil  vitamin a                na              22.5
# 3        NaN     oil         na                na                na
# 4    unknown     oil  vitamin a                na               NaN
#
#   fortification_standards  ...  \
# 0               voluntary  ...
# 1               mandatory  ...
# 2               mandatory  ...
# 3               mandatory  ...
# 4               mandatory  ...
#
#                                      source_citation  \
# 0  Grant J Aaron, Valerie M Friesen, Svenja Jungj...
# 1                                               GFDx
# 2                                               GFDx
# 3  Raghavan R, Aaron GJ, Nahar B, et al. Househol...
# 4                                                NaN
#
#                                          source_link source_year  \
# 0              https://doi.org/10.3945/jn.116.245753        2017
# 1  https://fortificationdata.org/country-fortific...        2018
# 2  https://fortificationdata.org/country-fortific...        2017
# 3  https://journals.plos.org/plosone/article?id=1...        2015
# 4  https://www.gainhealth.org/sites/default/files...         NaN
#
#                 source_type  source_additional  \
# 0                       NaN                NaN
# 1                       NaN                NaN
# 2                       NaN                NaN
# 3                       NaN                NaN
# 4  Survey - cross-sectional                NaN
#
#                                                notes       user date_recorded  \
# 0                                                NaN  nathaniel    10/30/2020
# 1                                     no uncertainty       yaqi    11/18/2020
# 2                                     no uncertainty       yaqi    11/18/2020
# 3                                     no uncertainty       yaqi    11/18/2020
# 4  Consumption of the fortified food vehicle was ...      rohit    11/24/2020
#
#   Validated Unnamed: 27
# 0       Yes         NaN
# 1       NaN         NaN
# 2       NaN         NaN
# 3       NaN         NaN
# 4       NaN         NaN
#
# [5 rows x 28 columns]

# %%
df = df.drop(columns=['location_id'])

# %%
df = loc_ids.merge(df, on = 'location_name', how = 'right')

# %%
df.head()
# Out:
#    location_id location_name subnational_name subnational_location_id  \
# 0          141         Egypt               na                     NaN
# 1          141         Egypt               na                     NaN
# 2          141         Egypt               na                     NaN
# 3          522         Sudan               na                     NaN
# 4          522         Sudan               na                     NaN
#
#    urbanicity      vehicle   nutrient nutrient_compound nutrient_mass_ppm  \
# 0         NaN  wheat flour         na                na               NaN
# 1         NaN  wheat flour         na                na                na
# 2         NaN  maize flour         na                na                na
# 3  mixed/both          oil  vitamin a                na               NaN
# 4  mixed/both          oil         na                na               NaN
#
#   fortification_standards  ... source_citation  \
# 0               mandatory  ...             NaN
# 1                      na  ...            GFDx
# 2                      na  ...            GFDx
# 3                 unknown  ...            GFDx
# 4                 unknown  ...            GFDx
#
#                                          source_link source_year  \
# 0       https://www.mdpi.com/2072-6643/11/7/1594/htm         NaN
# 1  https://fortificationdata.org/country-fortific...        2017
# 2  https://fortificationdata.org/country-fortific...        2017
# 3  https://fortificationdata.org/country-fortific...        2019
# 4  https://fortificationdata.org/country-fortific...        2019
#
#                 source_type  source_additional  \
# 0  Survey - cross-sectional                NaN
# 1                       NaN                NaN
# 2                       NaN                NaN
# 3                       NaN                NaN
# 4                       NaN                NaN
#
#                                                notes     user date_recorded  \
# 0  Data is in table S2 and they did not mention year    rohit    12/18/2020
# 1  Source for industrially processed: Magdy Sheha...  paulina    12/04/2020
# 2  Source for industrially processed: Magdy Sheha...  paulina    12/04/2020
# 3                                                NaN  beatrix    11/30/2020
# 4                                                NaN  beatrix    11/30/2020
#
#   Validated Unnamed: 27
# 0       NaN         NaN
# 1       NaN         NaN
# 2       NaN         NaN
# 3       NaN         NaN
# 4       NaN         NaN
#
# [5 rows x 28 columns]

# %%
assert(len(df[df.location_id.isna()])==0), "location_ids didn't merge properly"

# %% [markdown]
# ## save

# %%
df.loc[df.location_name=='Viet Nam','location_name'] = 'Vietnam' # FIX THIS AT THE ORIGIN

# %%
save_path = '/ihme/homes/beatrixh/notebooks/viv_rsc/data_prep/outputs/lsff_data_stage0.csv'
df.to_csv(save_path, index = False)
