# %%
from db_queries import get_population, get_ids
from db_queries import get_location_metadata as get_locs

# %%
import pandas as pd, numpy as np

# %%
location_names = ['India','Ethiopia','Nigeria']

# %%
gday_path =  '/ihme/homes/beatrixh/vivarium_data_analysis/pre_processing/lsff_project/data_prep/inputs/gday_extraction_sheet_02_22_2021.csv'
gday = pd.read_csv(gday_path)

# %%
gday.head()
# Out:
#    location_id location_name subnational_name  subnational_location_id  \
# 0        160.0   Afghanistan              NaN                      NaN
# 1        168.0        Angola              NaN                      NaN
# 2        168.0        Angola              NaN                      NaN
# 3        168.0        Angola              NaN                      NaN
# 4        168.0        Angola              NaN                      NaN
#
#    urbanicity      vehicle nutrient  \
# 0         NaN          NaN      NaN
# 1  mixed/both  wheat flour       na
# 2  mixed/both  maize flour       na
# 3  mixed/both  wheat flour       na
# 4  mixed/both  maize flour       na
#
#                                    value_description value_mean  \
# 0                                                NaN        NaN
# 1  Median amount of vehicle consumed on previous ...         49
# 2  Median amount of vehicle consumed on previous ...         72
# 3  Median amount of vehicle consumed on previous ...      89.32
# 4  Median amount of vehicle consumed on previous ...     154.99
#
#   value_025_percentile value_975_percentile    sub_population source_citation  \
# 0                  NaN                  NaN               NaN             NaN
# 1                  NaN                  NaN  total population             NaN
# 2                  NaN                  NaN  total population             NaN
# 3                  NaN                  NaN  total population            GFDx
# 4                  NaN                  NaN  total population            GFDx
#
#                                          source_link source_year  \
# 0                                                NaN         NaN
# 1  https://www.nutritionintl.org/content/user_fil...   1997-2000
# 2  https://www.nutritionintl.org/content/user_fil...   1997-2000
# 3  https://fortificationdata.org/country-fortific...        2019
# 4  https://fortificationdata.org/country-fortific...        2019
#
#                 source_type  \
# 0                       NaN
# 1  Survey - cross-sectional
# 2  Survey - cross-sectional
# 3                       NaN
# 4                       NaN
#
#                                                notes     user date_recorded
# 0                                                NaN      NaN           NaN
# 1  Estimates of wheat flour and maize meal consum...    rohit     12/2/2020
# 2  Estimates of wheat flour and maize meal consum...    rohit     12/2/2020
# 3          (grams/capita/day)Daily food availability  paulina    12/11/2020
# 4          (grams/capita/day)Daily food availability  paulina    12/11/2020

# %%
gday[gday.location_id.isna()].location_name.unique()
# Out:
# array(['China ', 'Egypt', 'Nepal', 'South Africa'], dtype=object)

# %%
assert(len(gday[gday.location_name.isna()])==0), "Some rows missing location name"

# %%
gday.location_id = gday.location_id.fillna(-1).astype(int)

# %%
gday.location_name.unique()
# Out:
# array(['Afghanistan', 'Angola', 'Bangladesh', 'Burkina Faso',
#        "Côte d'Ivoire", 'Cameroon', 'Chad', 'China ',
#        'Democratic Republic of the Congo', 'Egypt', 'Ethiopia', 'Ghana',
#        'India', 'Indonesia', 'Kenya', 'Madagascar', 'Mozambique',
#        'Myanmar', 'Nepal', 'Niger', 'Nigeria', 'Pakistan', 'Philippines',
#        'South Africa', 'Sudan', 'Uganda', 'United Republic of Tanzania',
#        'Viet Nam', 'Yemen', 'Zambia'], dtype=object)

# %%
gday[(gday.value_025_percentile.notna()) | (gday.value_025_percentile.notna())]
# Out:
#      location_id                location_name subnational_name  \
# 7            161                   Bangladesh               na
# 8            161                   Bangladesh               na
# 9            161                   Bangladesh               na
# 10           161                   Bangladesh               na
# 26           201                 Burkina Faso               na
# ..           ...                          ...              ...
# 197          189  United Republic of Tanzania               na
# 198          189  United Republic of Tanzania               na
# 201           20                     Viet Nam               na
# 204           20                     Viet Nam               na
# 205           20                     Viet Nam               na
#
#      subnational_location_id  urbanicity      vehicle nutrient  \
# 7                        NaN     unknown  wheat flour       na
# 8                        NaN     unknown  wheat flour       na
# 9                        NaN     unknown  wheat flour       na
# 10                       NaN  mixed/both          NaN     iron
# 26                       NaN     unknown  wheat flour       na
# ..                       ...         ...          ...      ...
# 197                      NaN     unknown  wheat flour       na
# 198                      NaN     unknown  maize flour       na
# 201                      NaN  mixed/both  wheat flour       na
# 204                      NaN     unknown  wheat flour       na
# 205                      NaN     unknown  wheat flour       na
#
#                                      value_description value_mean  \
# 7    Median amount of vehicle consumed on previous ...       77.9
# 8    Mean amount of vehicle consumed on previous da...         39
# 9    Mean amount of vehicle consumed on previous da...      49.48
# 10       Mean micronutrient intake per capita (mg/day)        7.4
# 26   Mean amount of vehicle consumed on previous da...      37.64
# ..                                                 ...        ...
# 197  Mean amount of vehicle consumed on previous da...      32.96
# 198  Mean amount of vehicle consumed on previous da...     172.47
# 201  Estimated daily contribution from fortified fo...       12.2
# 204  Median amount of vehicle consumed on previous ...         14
# 205  Median amount of vehicle consumed on previous ...      30.36
#
#     value_025_percentile value_975_percentile             sub_population  \
# 7                   63.8                   92  women of reproductive age
# 8                     na                   na           total population
# 9                     na                   na           total population
# 10                     7                    8  women of reproductive age
# 26                    na                   na           total population
# ..                   ...                  ...                        ...
# 197                   na                   na           total population
# 198                   na                   na           total population
# 201                  9.6                 15.3  women of reproductive age
# 204                   na                   na           total population
# 205                   na                   na           total population
#
#                                        source_citation  \
# 7    Leyvraz M, Laillou A, Rahman S, et al. An Asse...
# 8                                                  NaN
# 9                                                 GFDx
# 10                                                 NaN
# 26                                                GFDx
# ..                                                 ...
# 197                                               GFDx
# 198                                               GFDx
# 201  Improvement of the Vietnamese Diet for Women o...
# 204                                                NaN
# 205                                               GFDx
#
#                                            source_link source_year  \
# 7           https://www.mdpi.com/2072-6643/8/9/541/htm        2011
# 8    https://www.nutritionintl.org/content/user_fil...   1997-2000
# 9    https://fortificationdata.org/country-fortific...        2019
# 10   https://www.researchgate.net/publication/28558...        2011
# 26   https://fortificationdata.org/country-fortific...        2017
# ..                                                 ...         ...
# 197  https://fortificationdata.org/country-fortific...        2019
# 198  https://fortificationdata.org/country-fortific...        2017
# 201  https://journals.plos.org/plosone/article/file...        2010
# 204  https://www.nutritionintl.org/content/user_fil...   1997-2000
# 205  https://fortificationdata.org/country-fortific...        2017
#
#                   source_type  \
# 7    Survey - cross-sectional
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 26                        NaN
# ..                        ...
# 197                       NaN
# 198                       NaN
# 201  Survey - cross-sectional
# 204    Survey - other/unknown
# 205                       NaN
#
#                                                  notes     user date_recorded
# 7    Women of reproductive age 18-49 years , It doe...     yaqi    11/24/2020
# 8    Estimates of wheat flour and maize meal consum...  paulina    12/11/2020
# 9            (grams/capita/day)Daily food availability  paulina    12/11/2020
# 10   Women of reproductive age 15-49 years , It doe...    rohit    12/28/2020
# 26           (grams/capita/day)Daily food availability  paulina    12/11/2020
# ..                                                 ...      ...           ...
# 197          (grams/capita/day)Daily food availability  paulina    12/11/2020
# 198          (grams/capita/day)Daily food availability  paulina    12/11/2020
# 201  Estimated daily contribution from fortified fo...  paulina      11/23/20
# 204  Estimates of wheat flour and maize meal consum...  paulina       12/9/20
# 205          (grams/capita/day)Daily food availability  paulina    12/11/2020
#
# [127 rows x 19 columns]

# %%
## estimate CIs

from scipy.stats import variation

gday.loc[gday.value_mean=='na','value_mean'] = np.nan
gday.value_mean = gday.value_mean.astype(float)

cv = variation(gday[(gday.vehicle=="maize flour")].value_mean)
cvs = gday[(gday.value_mean!='na') & (gday.value_mean.notna())].groupby('vehicle').value_mean.apply(variation)
cvs.name = 'coeff_var'

gday = gday.merge(cvs, on = 'vehicle')
gday['dev'] = gday.value_mean * gday.coeff_var
gday[['value_mean','dev']]

gday['lower'] = (gday.value_mean - (1.282)*gday.dev).clip(lower = 0) #90th percentile
gday['upper'] = (gday.value_mean + (1.282)*gday.dev)

import matplotlib.pyplot as plt

plt.hist((gday.upper - gday.value_mean)/gday.value_mean)
plt.show
# Out:
# /ihme/code/central_comp/miniconda_svc-ccomp/envs/v105/lib/python3.7/site-packages/pandas/core/ops/__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)
# /ihme/code/central_comp/miniconda_svc-ccomp/envs/v105/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /ihme/code/central_comp/miniconda_svc-ccomp/envs/v105/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
value_d_to_metric = {
 'Median amount of vehicle consumed on previous day among consumers (g/day)': 'median',
 'Mean per capita consumption (g/day)': 'mean',
 'Mean amount of vehicle consumed on previous day among consumers (g/day)': 'mean',
 'Mean micronutrient intake per capita (mg/day)': 'mean',
 'Daily per capita consumption (g)': 'CHECK',
 'Daily consumption (mg/d)': 'CHECK',
 'Consumption per person per day (g)': 'CHECK',
 'Estimated daily contribution from fortified foods (mg/d)': 'CHECK',
 'kg/capita/year': 'CHECK'
}

# %%
value_d_to_entity = {
 'Median amount of vehicle consumed on previous day among consumers (g/day)': 'vehicle',
 'Mean per capita consumption (g/day)': 'CHECK',
 'Mean amount of vehicle consumed on previous day among consumers (g/day)': 'vehicle',
 'Mean micronutrient intake per capita (mg/day)': 'nutrient',
 'Daily per capita consumption (g)': 'CHECK',
 'Daily consumption (mg/d)': 'CHECK',
 'Consumption per person per day (g)': 'CHECK',
 'Estimated daily contribution from fortified foods (mg/d)': 'CHECK',
 'kg/capita/year': 'CHECK'
}

# %%
value_d_to_mass_unit = {
 'Median amount of vehicle consumed on previous day among consumers (g/day)': 'g',
 'Mean per capita consumption (g/day)': 'g',
 'Mean amount of vehicle consumed on previous day among consumers (g/day)': 'g',
 'Mean micronutrient intake per capita (mg/day)': 'mg',
 'Daily per capita consumption (g)': 'g',
 'Daily consumption (mg/d)': 'mg',
 'Consumption per person per day (g)': 'g',
 'Estimated daily contribution from fortified foods (mg/d)': 'mg',
 'kg/capita/year': 'kg'
}

# %%
value_d_to_time_unit = {
 'Median amount of vehicle consumed on previous day among consumers (g/day)': 'day',
 'Mean per capita consumption (g/day)': 'day',
 'Mean amount of vehicle consumed on previous day among consumers (g/day)': 'day',
 'Mean micronutrient intake per capita (mg/day)': 'day',
 'Daily per capita consumption (g)': 'day',
 'Daily consumption (mg/d)': 'day',
 'Consumption per person per day (g)': 'day',
 'Estimated daily contribution from fortified foods (mg/d)': 'day',
 'kg/capita/year': 'year'
}

# %%
value_d_to_population = {
 'Median amount of vehicle consumed on previous day among consumers (g/day)': 'consumers',
 'Mean per capita consumption (g/day)': 'capita CHECK',
 'Mean amount of vehicle consumed on previous day among consumers (g/day)': 'consumers',
 'Mean micronutrient intake per capita (mg/day)': 'capita CHECK',
 'Daily per capita consumption (g)': 'capita CHECK',
 'Daily consumption (mg/d)': 'CHECK',
 'Consumption per person per day (g)': 'CHECK',
 'Estimated daily contribution from fortified foods (mg/d)': 'CHECK',
 'kg/capita/year': 'CHECK'
}

# %%
def format_value_d(df):
    df['metric'] = df.value_description.map(value_d_to_metric)
    df['entity'] = df.value_description.map(value_d_to_entity)
    df['mass_unit'] = df.value_description.map(value_d_to_mass_unit)
    df['time_unit'] = df.value_description.map(value_d_to_time_unit)
    df['pop_denom'] = df.value_description.map(value_d_to_population)
    
    return df

# %%
nigeria = gday[gday.location_name=="Nigeria"]

nigeria = format_value_d(nigeria)
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
loc_metadata = get_locs(location_set_id=35, gbd_round_id=6, decomp_step="step4")

# %%
nigeria_subnat_ids = {
    'Ebonyi':25328,
    'Sokoto':25351
}

# %%
pop = get_population(age_group_id=22, 
                     location_id=list(nigeria_subnat_ids.values()),
                     year_id=2018,
                     sex_id=3,
                     gbd_round_id=6, 
                     decomp_step='step5')

# %%
nigeria['subnational_id'] = nigeria.subnational_name.map(nigeria_subnat_ids)
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
nigeria = nigeria.merge(pop[['location_id','population']].rename(columns={'location_id':'subnational_id'}), on = 'subnational_id', how = 'left')

# %%
nigeria.sort_values('vehicle')
# Out:
#     location_id location_name subnational_name  subnational_location_id  \
# 6           214       Nigeria           Ebonyi                      NaN
# 7           214       Nigeria           Sokoto                      NaN
# 2           214       Nigeria               na                      NaN
# 3           214       Nigeria               na                      NaN
# 4           214       Nigeria              NaN                      NaN
# 9           214       Nigeria               na                      NaN
# 10          214       Nigeria           Ebonyi                      NaN
# 11          214       Nigeria           Sokoto                      NaN
# 12          214       Nigeria               na                      NaN
# 8           214       Nigeria               na                      NaN
# 0           214       Nigeria               na                      NaN
# 1           214       Nigeria               na                      NaN
# 5           214       Nigeria               na                      NaN
#
#    urbanicity                        vehicle nutrient  \
# 6     unknown                       bouillon       na
# 7     unknown                       bouillon       na
# 2     unknown                    maize flour       na
# 3     unknown                    maize flour       na
# 4         NaN                    maize flour       na
# 9     unknown                           rice       na
# 10    unknown                           rice       na
# 11    unknown                           rice       na
# 12    unknown                           rice       na
# 8     unknown                           salt       na
# 0     unknown                    wheat flour       na
# 1     unknown                    wheat flour       na
# 5         NaN  wheat(not specifically flour)       na
#
#                                     value_description  value_mean  \
# 6   Mean amount of vehicle consumed on previous da...        2.00
# 7   Mean amount of vehicle consumed on previous da...        3.00
# 2   Mean amount of vehicle consumed on previous da...       54.00
# 3                 Mean per capita consumption (g/day)       95.10
# 4                 Mean per capita consumption (g/day)       69.70
# 9                 Mean per capita consumption (g/day)      126.90
# 10  Mean amount of vehicle consumed on previous da...       80.00
# 11  Mean amount of vehicle consumed on previous da...       97.00
# 12                 Consumption per person per day (g)       77.00
# 8   Mean amount of vehicle consumed on previous da...        7.20
# 0   Mean amount of vehicle consumed on previous da...       26.00
# 1                 Mean per capita consumption (g/day)       49.15
# 5                 Mean per capita consumption (g/day)       54.49
#
#    value_025_percentile  ...        dev      lower       upper metric  \
# 6                    na  ...   0.596133   1.235757    2.764243   mean
# 7                    na  ...   0.894200   1.853635    4.146365   mean
# 2                    na  ...  35.567618   8.402314   99.597686   mean
# 3                    na  ...  62.638527  14.797408  175.402592   mean
# 4                   NaN  ...  45.908573  10.845209  128.554791   mean
# 9                    na  ...  73.621781  32.516876  221.283124   mean
# 10                   na  ...  46.412471  20.499213  139.500787   mean
# 11                   na  ...  56.275121  24.855295  169.144705   mean
# 12                   na  ...  44.672003  19.730492  134.269508  CHECK
# 8                    na  ...   1.464328   5.322732    9.077268   mean
# 0                    na  ...  24.187969   0.000000   57.008976   mean
# 1                    na  ...  45.724564   0.000000  107.768891   mean
# 5                   NaN  ...  36.328136   7.917330  101.062670   mean
#
#      entity mass_unit time_unit     pop_denom subnational_id    population
# 6   vehicle         g       day     consumers        25328.0  3.163671e+06
# 7   vehicle         g       day     consumers        25351.0  6.384879e+06
# 2   vehicle         g       day     consumers            NaN           NaN
# 3     CHECK         g       day  capita CHECK            NaN           NaN
# 4     CHECK         g       day  capita CHECK            NaN           NaN
# 9     CHECK         g       day  capita CHECK            NaN           NaN
# 10  vehicle         g       day     consumers        25328.0  3.163671e+06
# 11  vehicle         g       day     consumers        25351.0  6.384879e+06
# 12    CHECK         g       day         CHECK            NaN           NaN
# 8   vehicle         g       day     consumers            NaN           NaN
# 0   vehicle         g       day     consumers            NaN           NaN
# 1     CHECK         g       day  capita CHECK            NaN           NaN
# 5     CHECK         g       day  capita CHECK            NaN           NaN
#
# [13 rows x 30 columns]

# %%
## we can population-weight bouillon

# %%
nigeria[nigeria.vehicle=="bouillon"][['metric', 'vehicle', 'entity', 'mass_unit', 'time_unit',
       'pop_denom','source_year','value_mean','source_citation','source_link','sub_population','subnational_name']]
# Out:
#   metric   vehicle   entity mass_unit time_unit  pop_denom source_year  \
# 6   mean  bouillon  vehicle         g       day  consumers        2018
# 7   mean  bouillon  vehicle         g       day  consumers        2018
#
#    value_mean source_citation  \
# 6         2.0             NaN
# 7         3.0             NaN
#
#                                          source_link  \
# 6  https://www.gainhealth.org/sites/default/files...
# 7  https://www.gainhealth.org/sites/default/files...
#
#               sub_population subnational_name
# 6  women of reproductive age           Ebonyi
# 7  women of reproductive age           Sokoto

# %%
nigeria.iloc[6].source_link
# Out:
# 'https://www.gainhealth.org/sites/default/files/publications/documents/identifying-potential-new-food-vehicles-for-fortification-in-west-africa-2018.pdf'

# %%
output = output.append(nigeria[nigeria.vehicle=="bouillon"])

# %%
view_cols = ['vehicle','metric', 'entity', 'mass_unit', 'time_unit',
       'pop_denom','source_year','value_mean','source_citation','source_link','sub_population','subnational_name']

# %%
nigeria.loc[nigeria.vehicle=="maize flour",view_cols]
# Out:
#        vehicle metric   entity mass_unit time_unit     pop_denom source_year  \
# 2  maize flour   mean  vehicle         g       day     consumers   1997-2000
# 3  maize flour   mean    CHECK         g       day  capita CHECK        2017
# 4  maize flour   mean    CHECK         g       day  capita CHECK        2007
#
#    value_mean                                    source_citation  \
# 2        54.0                                                NaN
# 3        95.1                                               GFDx
# 4        69.7  Nuss, E. T., & Tanumihardjo, S. A. (2011). Qua...
#
#                                          source_link    sub_population  \
# 2  https://www.nutritionintl.org/content/user_fil...  total population
# 3  https://fortificationdata.org/country-fortific...  total population
# 4              https://doi.org/10.3945/an.110.000182  total population
#
#   subnational_name
# 2               na
# 3               na
# 4              NaN

# %%
# use most recent maize flour data (these all come from FAO, some via different methods)

# %%
nigeria.loc[(nigeria.vehicle=="maize flour") & (nigeria.source_year=="2017")]
# Out:
#    location_id location_name subnational_name  subnational_location_id  \
# 3          214       Nigeria               na                      NaN
#
#   urbanicity      vehicle nutrient                    value_description  \
# 3    unknown  maize flour       na  Mean per capita consumption (g/day)
#
#    value_mean value_025_percentile  ...        dev      lower       upper  \
# 3        95.1                   na  ...  62.638527  14.797408  175.402592
#
#   metric entity mass_unit time_unit     pop_denom subnational_id  population
# 3   mean  CHECK         g       day  capita CHECK            NaN         NaN
#
# [1 rows x 30 columns]

# %%
output = output.append(nigeria.loc[(nigeria.vehicle=="maize flour") & (nigeria.source_year=="2017")])

# %%
nigeria.loc[nigeria.vehicle=="rice",['metric', 'entity', 'mass_unit', 'time_unit',
       'pop_denom','source_year','value_mean','source_citation','source_link','sub_population','subnational_name']]
# Out:
#    metric   entity mass_unit time_unit     pop_denom source_year  value_mean  \
# 9    mean    CHECK         g       day  capita CHECK        2017       126.9
# 10   mean  vehicle         g       day     consumers        2018        80.0
# 11   mean  vehicle         g       day     consumers        2018        97.0
# 12  CHECK    CHECK         g       day         CHECK        2013        77.0
#
#    source_citation                                        source_link  \
# 9             GFDx  https://fortificationdata.org/country-fortific...
# 10             NaN  https://www.gainhealth.org/sites/default/files...
# 11             NaN  https://www.gainhealth.org/sites/default/files...
# 12             NaN  https://issuu.com/sight_and_life/docs/sightand...
#
#                sub_population subnational_name
# 9            total population               na
# 10  women of reproductive age           Ebonyi
# 11  women of reproductive age           Sokoto
# 12           total population               na

# %%
# for rice, use the WRA numbers

# %%
nigeria.loc[(nigeria.vehicle=="rice") & (nigeria.sub_population=="women of reproductive age"),['metric', 'entity', 'mass_unit', 'time_unit',
       'pop_denom','source_year','value_mean','source_citation','source_link','sub_population','subnational_name']]
# Out:
#    metric   entity mass_unit time_unit  pop_denom source_year  value_mean  \
# 10   mean  vehicle         g       day  consumers        2018        80.0
# 11   mean  vehicle         g       day  consumers        2018        97.0
#
#    source_citation                                        source_link  \
# 10             NaN  https://www.gainhealth.org/sites/default/files...
# 11             NaN  https://www.gainhealth.org/sites/default/files...
#
#                sub_population subnational_name
# 10  women of reproductive age           Ebonyi
# 11  women of reproductive age           Sokoto

# %%
output = output.append(nigeria.loc[(nigeria.vehicle=="rice") & (nigeria.sub_population=="women of reproductive age"),])

# %%
# we only have one salt number

# %%
nigeria.loc[nigeria.vehicle=="salt",['metric', 'entity', 'mass_unit', 'time_unit',
       'pop_denom','source_year','value_mean','source_citation','source_link','sub_population','subnational_name']]
# Out:
#   metric   entity mass_unit time_unit  pop_denom source_year  value_mean  \
# 8   mean  vehicle         g       day  consumers        2017         7.2
#
#   source_citation                                        source_link  \
# 8            GFDx  https://fortificationdata.org/country-fortific...
#
#      sub_population subnational_name
# 8  total population               na

# %%
output = output.append(nigeria.loc[nigeria.vehicle=="salt",])

# %%
nigeria.loc[["wheat" in i for i in nigeria.vehicle],['vehicle','metric', 'entity', 'mass_unit', 'time_unit',
       'pop_denom','source_year','value_mean','source_citation','source_link','sub_population','subnational_name']]
# Out:
#                          vehicle metric   entity mass_unit time_unit  \
# 0                    wheat flour   mean  vehicle         g       day
# 1                    wheat flour   mean    CHECK         g       day
# 5  wheat(not specifically flour)   mean    CHECK         g       day
#
#       pop_denom source_year  value_mean  \
# 0     consumers   1997-2000       26.00
# 1  capita CHECK        2017       49.15
# 5  capita CHECK   2000-2009       54.49
#
#                                      source_citation  \
# 0                                                NaN
# 1                                               GFDx
# 5  Mason, N. M., Jayne, T. S., & Shiferaw, B. A. ...
#
#                                          source_link    sub_population  \
# 0  https://www.nutritionintl.org/content/user_fil...  total population
# 1  https://fortificationdata.org/country-fortific...  total population
# 5  https://ageconsearch.umn.edu/record/146936/fil...  total population
#
#   subnational_name
# 0               na
# 1               na
# 5               na

# %%
## for wheat flour, take most recent year

# %%
nigeria.loc[(["wheat" in i for i in nigeria.vehicle]) & (nigeria.source_year=="2017") ,['vehicle','metric', 'entity', 'mass_unit', 'time_unit',
       'pop_denom','source_year','value_mean','source_citation','source_link','sub_population','subnational_name']]
# Out:
#        vehicle metric entity mass_unit time_unit     pop_denom source_year  \
# 1  wheat flour   mean  CHECK         g       day  capita CHECK        2017
#
#    value_mean source_citation  \
# 1       49.15            GFDx
#
#                                          source_link    sub_population  \
# 1  https://fortificationdata.org/country-fortific...  total population
#
#   subnational_name
# 1               na

# %%
output = output.append(nigeria.loc[(["wheat" in i for i in nigeria.vehicle]) & (nigeria.source_year=="2017") ,])

# %% [markdown]
# ## ethiopia

# %%
ethiopia = gday[gday.location_name=="Ethiopia"]
ethiopia = format_value_d(ethiopia)
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
ethiopia.sort_values('vehicle')
# Out:
#      location_id location_name subnational_name  subnational_location_id  \
# 108          179      Ethiopia               na                      NaN
# 109          179      Ethiopia              NaN                      NaN
# 190          179      Ethiopia               na                      NaN
# 45           179      Ethiopia               na                      NaN
# 46           179      Ethiopia               na                      NaN
# 139          179      Ethiopia               na                      NaN
#
#     urbanicity                        vehicle nutrient  \
# 108    unknown                    maize flour       na
# 109        NaN                    maize flour       na
# 190    unknown                           salt       na
# 45     unknown                    wheat flour       na
# 46     unknown                    wheat flour       na
# 139        NaN  wheat(not specifically flour)       na
#
#                                      value_description  value_mean  \
# 108                Mean per capita consumption (g/day)      113.84
# 109                Mean per capita consumption (g/day)      113.60
# 190                Mean per capita consumption (g/day)        5.80
# 45   Mean amount of vehicle consumed on previous da...       54.00
# 46                 Mean per capita consumption (g/day)       97.64
# 139                Mean per capita consumption (g/day)       92.74
#
#     value_025_percentile  ... date_recorded coeff_var        dev      lower  \
# 108                   na  ...    12/11/2020  0.658660  74.981808  17.713322
# 109                  NaN  ...    12/17/2020  0.658660  74.823729  17.675979
# 190                   na  ...    12/11/2020  0.203379   1.179597   4.287756
# 45                    na  ...    12/11/2020  0.930306  50.236551   0.000000
# 46                    na  ...    12/11/2020  0.930306  90.835126   0.000000
# 139                  NaN  ...    12/17/2020  0.666694  61.829167  13.475008
#
#           upper metric   entity mass_unit time_unit     pop_denom
# 108  209.966678   mean    CHECK         g       day  capita CHECK
# 109  209.524021   mean    CHECK         g       day  capita CHECK
# 190    7.312244   mean    CHECK         g       day  capita CHECK
# 45   118.403258   mean  vehicle         g       day     consumers
# 46   214.090631   mean    CHECK         g       day  capita CHECK
# 139  172.004992   mean    CHECK         g       day  capita CHECK
#
# [6 rows x 28 columns]

# %%
ethiopia.sort_values('vehicle')[['metric', 'entity', 'mass_unit', 'time_unit',
       'pop_denom','source_year','value_mean','source_citation','source_link','sub_population','subnational_name']]
# Out:
#     metric   entity mass_unit time_unit     pop_denom source_year  value_mean  \
# 108   mean    CHECK         g       day  capita CHECK        2017      113.84
# 109   mean    CHECK         g       day  capita CHECK        2007      113.60
# 190   mean    CHECK         g       day  capita CHECK        2017        5.80
# 45    mean  vehicle         g       day     consumers   1997-2000       54.00
# 46    mean    CHECK         g       day  capita CHECK        2017       97.64
# 139   mean    CHECK         g       day  capita CHECK   2000-2009       92.74
#
#                                        source_citation  \
# 108                                                NaN
# 109  Nuss, E. T., & Tanumihardjo, S. A. (2011). Qua...
# 190                                                NaN
# 45                                                 NaN
# 46                                                 NaN
# 139  Mason, N. M., Jayne, T. S., & Shiferaw, B. A. ...
#
#                                            source_link    sub_population  \
# 108  https://fortificationdata.org/country-fortific...  total population
# 109              https://doi.org/10.3945/an.110.000182  total population
# 190  https://fortificationdata.org/country-fortific...  total population
# 45   https://www.nutritionintl.org/content/user_fil...  total population
# 46   https://fortificationdata.org/country-fortific...  total population
# 139  https://ageconsearch.umn.edu/record/146936/fil...  total population
#
#     subnational_name
# 108               na
# 109              NaN
# 190               na
# 45                na
# 46                na
# 139               na

# %%
ethiopia[ethiopia.vehicle=="maize flour"][['metric', 'entity', 'mass_unit', 'time_unit',
       'pop_denom','source_year','value_mean','source_citation','source_link','sub_population','subnational_name']]
# Out:
#     metric entity mass_unit time_unit     pop_denom source_year  value_mean  \
# 108   mean  CHECK         g       day  capita CHECK        2017      113.84
# 109   mean  CHECK         g       day  capita CHECK        2007      113.60
#
#                                        source_citation  \
# 108                                                NaN
# 109  Nuss, E. T., & Tanumihardjo, S. A. (2011). Qua...
#
#                                            source_link    sub_population  \
# 108  https://fortificationdata.org/country-fortific...  total population
# 109              https://doi.org/10.3945/an.110.000182  total population
#
#     subnational_name
# 108               na
# 109              NaN

# %%
## take the more recent one
ethiopia[(ethiopia.vehicle=="maize flour") & (ethiopia.source_year=="2017")][['metric', 'entity', 'mass_unit', 'time_unit',
       'pop_denom','source_year','value_mean','source_citation','source_link','sub_population','subnational_name']]
# Out:
#     metric entity mass_unit time_unit     pop_denom source_year  value_mean  \
# 108   mean  CHECK         g       day  capita CHECK        2017      113.84
#
#     source_citation                                        source_link  \
# 108             NaN  https://fortificationdata.org/country-fortific...
#
#        sub_population subnational_name
# 108  total population               na

# %%
output = output.append(ethiopia[(ethiopia.vehicle=="maize flour") & (ethiopia.source_year=="2017")])
# Out:
# /ihme/code/central_comp/miniconda_svc-ccomp/envs/v105/lib/python3.7/site-packages/pandas/core/frame.py:7138: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,

# %%
# only one salt number
ethiopia[ethiopia.vehicle=="salt"][['metric', 'entity', 'mass_unit', 'time_unit',
       'pop_denom','source_year','value_mean','source_citation','source_link','sub_population','subnational_name']]
# Out:
#     metric entity mass_unit time_unit     pop_denom source_year  value_mean  \
# 190   mean  CHECK         g       day  capita CHECK        2017         5.8
#
#     source_citation                                        source_link  \
# 190             NaN  https://fortificationdata.org/country-fortific...
#
#        sub_population subnational_name
# 190  total population               na

# %%
output = output.append(ethiopia[ethiopia.vehicle=="salt"])

# %%
ethiopia[(["wheat" in i for i in ethiopia.vehicle])][['vehicle','metric', 'entity', 'mass_unit', 'time_unit',
       'pop_denom','source_year','value_mean','source_citation','source_link','sub_population','subnational_name']]
# Out:
#                            vehicle metric   entity mass_unit time_unit  \
# 45                     wheat flour   mean  vehicle         g       day
# 46                     wheat flour   mean    CHECK         g       day
# 139  wheat(not specifically flour)   mean    CHECK         g       day
#
#         pop_denom source_year  value_mean  \
# 45      consumers   1997-2000       54.00
# 46   capita CHECK        2017       97.64
# 139  capita CHECK   2000-2009       92.74
#
#                                        source_citation  \
# 45                                                 NaN
# 46                                                 NaN
# 139  Mason, N. M., Jayne, T. S., & Shiferaw, B. A. ...
#
#                                            source_link    sub_population  \
# 45   https://www.nutritionintl.org/content/user_fil...  total population
# 46   https://fortificationdata.org/country-fortific...  total population
# 139  https://ageconsearch.umn.edu/record/146936/fil...  total population
#
#     subnational_name
# 45                na
# 46                na
# 139               na

# %%
## take most recent
ethiopia[(["wheat" in i for i in ethiopia.vehicle]) & (ethiopia.source_year=="2017")][['metric', 'entity', 'mass_unit', 'time_unit',
       'pop_denom','source_year','value_mean','source_citation','source_link','sub_population','subnational_name']]
# Out:
#    metric entity mass_unit time_unit     pop_denom source_year  value_mean  \
# 46   mean  CHECK         g       day  capita CHECK        2017       97.64
#
#    source_citation                                        source_link  \
# 46             NaN  https://fortificationdata.org/country-fortific...
#
#       sub_population subnational_name
# 46  total population               na

# %%
output = output.append(ethiopia[(["wheat" in i for i in ethiopia.vehicle]) & (ethiopia.source_year=="2017")])

# %% [markdown]
# ## india

# %%
india = gday[gday.location_name=="India"]
india = format_value_d(india)
# Out:
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /ihme/homes/beatrixh/.local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
india.sort_values('vehicle')
# Out:
#      location_id location_name subnational_name  subnational_location_id  \
# 195          163         India               na                      NaN
# 196          163         India               na                      NaN
# 191          163         India               na                      NaN
# 50           163         India               na                      NaN
# 51           163         India               na                      NaN
#
#      urbanicity      vehicle nutrient  \
# 195  mixed/both         rice       na
# 196  mixed/both         rice       na
# 191  mixed/both         salt       na
# 50   mixed/both  wheat flour       na
# 51   mixed/both  wheat flour       na
#
#                                      value_description  value_mean  \
# 195                Mean per capita consumption (g/day)      282.77
# 196                Mean per capita consumption (g/day)      291.00
# 191  Mean amount of vehicle consumed on previous da...        9.50
# 50                 Mean per capita consumption (g/day)      169.62
# 51                 Mean per capita consumption (g/day)      164.00
#
#     value_025_percentile  ... date_recorded coeff_var         dev      lower  \
# 195                  NaN  ...    12/10/2020  0.580156  164.050679  72.457030
# 196                  NaN  ...    12/15/2020  0.580156  168.825362  74.565886
# 191                  NaN  ...    12/10/2020  0.203379    1.932099   7.023049
# 50                   NaN  ...    12/10/2020  0.930306  157.798587   0.000000
# 51                   NaN  ...    12/15/2020  0.930306  152.570265   0.000000
#
#           upper metric   entity mass_unit time_unit     pop_denom
# 195  493.082970   mean    CHECK         g       day  capita CHECK
# 196  507.434114   mean    CHECK         g       day  capita CHECK
# 191   11.976951   mean  vehicle         g       day     consumers
# 50   371.917789   mean    CHECK         g       day  capita CHECK
# 51   359.595079   mean    CHECK         g       day  capita CHECK
#
# [5 rows x 28 columns]

# %%
india.sort_values('vehicle')[['metric', 'vehicle' ,'entity', 'mass_unit', 'time_unit',
       'pop_denom','source_year','value_mean','source_citation','source_link','sub_population','subnational_name']]
# Out:
#     metric      vehicle   entity mass_unit time_unit     pop_denom  \
# 195   mean         rice    CHECK         g       day  capita CHECK
# 196   mean         rice    CHECK         g       day  capita CHECK
# 191   mean         salt  vehicle         g       day     consumers
# 50    mean  wheat flour    CHECK         g       day  capita CHECK
# 51    mean  wheat flour    CHECK         g       day  capita CHECK
#
#     source_year  value_mean source_citation  \
# 195        2018      282.77             NaN
# 196        2007      291.00             NaN
# 191        2018        9.50             NaN
# 50         2018      169.62             NaN
# 51         2007      164.00             NaN
#
#                                            source_link    sub_population  \
# 195  https://fortificationdata.org/country-fortific...  total population
# 196  https://www.hunger-undernutrition.org/blog/201...  total population
# 191  https://fortificationdata.org/country-fortific...  total population
# 50   https://fortificationdata.org/country-fortific...  total population
# 51   https://www.hunger-undernutrition.org/blog/201...  total population
#
#     subnational_name
# 195               na
# 196               na
# 191               na
# 50                na
# 51                na

# %%
#take more recent datapoint

india[(india.vehicle=="rice")][['metric', 'vehicle' ,'entity', 'mass_unit', 'time_unit',
       'pop_denom','source_year','value_mean','source_citation','source_link','sub_population','subnational_name']]
# Out:
#     metric vehicle entity mass_unit time_unit     pop_denom source_year  \
# 195   mean    rice  CHECK         g       day  capita CHECK        2018
# 196   mean    rice  CHECK         g       day  capita CHECK        2007
#
#      value_mean source_citation  \
# 195      282.77             NaN
# 196      291.00             NaN
#
#                                            source_link    sub_population  \
# 195  https://fortificationdata.org/country-fortific...  total population
# 196  https://www.hunger-undernutrition.org/blog/201...  total population
#
#     subnational_name
# 195               na
# 196               na

# %%
#take more recent datapoint

india[(india.vehicle=="rice") & (india.source_year=="2018")][['metric', 'vehicle' ,'entity', 'mass_unit', 'time_unit',
       'pop_denom','source_year','value_mean','source_citation','source_link','sub_population','subnational_name']]
# Out:
#     metric vehicle entity mass_unit time_unit     pop_denom source_year  \
# 195   mean    rice  CHECK         g       day  capita CHECK        2018
#
#      value_mean source_citation  \
# 195      282.77             NaN
#
#                                            source_link    sub_population  \
# 195  https://fortificationdata.org/country-fortific...  total population
#
#     subnational_name
# 195               na

# %%
output = output.append(india[(india.vehicle=="rice") & (india.source_year=="2018")])

# %%
#only one datapoint
india[(india.vehicle=="salt")][['metric', 'vehicle' ,'entity', 'mass_unit', 'time_unit',
       'pop_denom','source_year','value_mean','source_citation','source_link','sub_population','subnational_name']]
# Out:
#     metric vehicle   entity mass_unit time_unit  pop_denom source_year  \
# 191   mean    salt  vehicle         g       day  consumers        2018
#
#      value_mean source_citation  \
# 191         9.5             NaN
#
#                                            source_link    sub_population  \
# 191  https://fortificationdata.org/country-fortific...  total population
#
#     subnational_name
# 191               na

# %%
output = output.append(india[(india.vehicle=="salt")])

# %%
india[(["wheat" in i for i in india.vehicle])][['metric', 'entity', 'mass_unit', 'time_unit',
       'pop_denom','source_year','value_mean','source_citation','source_link','sub_population','subnational_name']]
# Out:
#    metric entity mass_unit time_unit     pop_denom source_year  value_mean  \
# 50   mean  CHECK         g       day  capita CHECK        2018      169.62
# 51   mean  CHECK         g       day  capita CHECK        2007      164.00
#
#    source_citation                                        source_link  \
# 50             NaN  https://fortificationdata.org/country-fortific...
# 51             NaN  https://www.hunger-undernutrition.org/blog/201...
#
#       sub_population subnational_name
# 50  total population               na
# 51  total population               na

# %%
## take most recent
india[(["wheat" in i for i in india.vehicle]) & (india.source_year=="2018")][['metric', 'entity', 'mass_unit', 'time_unit',
       'pop_denom','source_year','value_mean','source_citation','source_link','sub_population','subnational_name']]
# Out:
#    metric entity mass_unit time_unit     pop_denom source_year  value_mean  \
# 50   mean  CHECK         g       day  capita CHECK        2018      169.62
#
#    source_citation                                        source_link  \
# 50             NaN  https://fortificationdata.org/country-fortific...
#
#       sub_population subnational_name
# 50  total population               na

# %%
output = output.append(india[(["wheat" in i for i in india.vehicle]) & (india.source_year=="2018")])

# %% [markdown]
# ## format output

# %%
output.pop_denom = output.pop_denom.map({'consumers': 'consumers', 'capita CHECK': 'capita'})

# %%
output.value_mean = output.value_mean.astype(float)

# %%
output.value_025_percentile = output.value_025_percentile.map({'na':np.nan}).astype(float)
output.value_975_percentile = output.value_975_percentile.map({'na':np.nan}).astype(float)

# %%
vet_cols = ['entity', 'location_name', 'mass_unit',
       'metric', 'notes', 'nutrient', 'pop_denom', 'population', 'source_link',
       'sub_population', 'subnational_id',
       'subnational_name', 'time_unit', 'urbanicity', 'user', 'value_description',
       'value_mean','vehicle']

output[vet_cols]
# Out:
#       entity location_name mass_unit metric  \
# 6    vehicle       Nigeria         g   mean
# 7    vehicle       Nigeria         g   mean
# 3      CHECK       Nigeria         g   mean
# 10   vehicle       Nigeria         g   mean
# 11   vehicle       Nigeria         g   mean
# 8    vehicle       Nigeria         g   mean
# 1      CHECK       Nigeria         g   mean
# 108    CHECK      Ethiopia         g   mean
# 190    CHECK      Ethiopia         g   mean
# 46     CHECK      Ethiopia         g   mean
# 195    CHECK         India         g   mean
# 191  vehicle         India         g   mean
# 50     CHECK         India         g   mean
#
#                                                  notes nutrient  pop_denom  \
# 6    in terms of consumption patterns, women of rep...       na  consumers
# 7    in terms of consumption patterns, women of rep...       na  consumers
# 3            (grams/capita/day)Daily food availability       na     capita
# 10   in terms of consumption patterns, women of rep...       na  consumers
# 11   in terms of consumption patterns, women of rep...       na  consumers
# 8            (grams/capita/day)Daily food availability       na  consumers
# 1            (grams/capita/day)Daily food availability       na     capita
# 108          (grams/capita/day)Daily food availability       na     capita
# 190          (grams/capita/day)Daily food availability       na     capita
# 46           (grams/capita/day)Daily food availability       na     capita
# 195                                                NaN       na     capita
# 191                                                NaN       na  consumers
# 50                                                 NaN       na     capita
#
#        population                                        source_link  \
# 6    3.163671e+06  https://www.gainhealth.org/sites/default/files...
# 7    6.384879e+06  https://www.gainhealth.org/sites/default/files...
# 3             NaN  https://fortificationdata.org/country-fortific...
# 10   3.163671e+06  https://www.gainhealth.org/sites/default/files...
# 11   6.384879e+06  https://www.gainhealth.org/sites/default/files...
# 8             NaN  https://fortificationdata.org/country-fortific...
# 1             NaN  https://fortificationdata.org/country-fortific...
# 108           NaN  https://fortificationdata.org/country-fortific...
# 190           NaN  https://fortificationdata.org/country-fortific...
# 46            NaN  https://fortificationdata.org/country-fortific...
# 195           NaN  https://fortificationdata.org/country-fortific...
# 191           NaN  https://fortificationdata.org/country-fortific...
# 50            NaN  https://fortificationdata.org/country-fortific...
#
#                 sub_population  subnational_id subnational_name time_unit  \
# 6    women of reproductive age         25328.0           Ebonyi       day
# 7    women of reproductive age         25351.0           Sokoto       day
# 3             total population             NaN               na       day
# 10   women of reproductive age         25328.0           Ebonyi       day
# 11   women of reproductive age         25351.0           Sokoto       day
# 8             total population             NaN               na       day
# 1             total population             NaN               na       day
# 108           total population             NaN               na       day
# 190           total population             NaN               na       day
# 46            total population             NaN               na       day
# 195           total population             NaN               na       day
# 191           total population             NaN               na       day
# 50            total population             NaN               na       day
#
#      urbanicity     user                                  value_description  \
# 6       unknown  paulina  Mean amount of vehicle consumed on previous da...
# 7       unknown  paulina  Mean amount of vehicle consumed on previous da...
# 3       unknown  paulina                Mean per capita consumption (g/day)
# 10      unknown  paulina  Mean amount of vehicle consumed on previous da...
# 11      unknown  paulina  Mean amount of vehicle consumed on previous da...
# 8       unknown  paulina  Mean amount of vehicle consumed on previous da...
# 1       unknown  paulina                Mean per capita consumption (g/day)
# 108     unknown  paulina                Mean per capita consumption (g/day)
# 190     unknown  paulina                Mean per capita consumption (g/day)
# 46      unknown  paulina                Mean per capita consumption (g/day)
# 195  mixed/both    rohit                Mean per capita consumption (g/day)
# 191  mixed/both    rohit  Mean amount of vehicle consumed on previous da...
# 50   mixed/both    rohit                Mean per capita consumption (g/day)
#
#      value_mean      vehicle
# 6          2.00     bouillon
# 7          3.00     bouillon
# 3         95.10  maize flour
# 10        80.00         rice
# 11        97.00         rice
# 8          7.20         salt
# 1         49.15  wheat flour
# 108      113.84  maize flour
# 190        5.80         salt
# 46        97.64  wheat flour
# 195      282.77         rice
# 191        9.50         salt
# 50       169.62  wheat flour

# %%
#for now we'll drop percentiles, then add back in
output[['location_name','vehicle','value_mean','value_025_percentile','value_025_percentile','lower','upper']]
# Out:
#     location_name      vehicle  value_mean  value_025_percentile  \
# 6         Nigeria     bouillon        2.00                   NaN
# 7         Nigeria     bouillon        3.00                   NaN
# 3         Nigeria  maize flour       95.10                   NaN
# 10        Nigeria         rice       80.00                   NaN
# 11        Nigeria         rice       97.00                   NaN
# 8         Nigeria         salt        7.20                   NaN
# 1         Nigeria  wheat flour       49.15                   NaN
# 108      Ethiopia  maize flour      113.84                   NaN
# 190      Ethiopia         salt        5.80                   NaN
# 46       Ethiopia  wheat flour       97.64                   NaN
# 195         India         rice      282.77                   NaN
# 191         India         salt        9.50                   NaN
# 50          India  wheat flour      169.62                   NaN
#
#      value_025_percentile      lower       upper
# 6                     NaN   1.235757    2.764243
# 7                     NaN   1.853635    4.146365
# 3                     NaN  14.797408  175.402592
# 10                    NaN  20.499213  139.500787
# 11                    NaN  24.855295  169.144705
# 8                     NaN   5.322732    9.077268
# 1                     NaN   0.000000  107.768891
# 108                   NaN  17.713322  209.966678
# 190                   NaN   4.287756    7.312244
# 46                    NaN   0.000000  214.090631
# 195                   NaN  72.457030  493.082970
# 191                   NaN   7.023049   11.976951
# 50                    NaN   0.000000  371.917789

# %%
group_cols = ['location_id','location_name','sub_population','vehicle','metric','mass_unit','time_unit','pop_denom'] #,'subnational_name']

# %%
# weight by subnational population
output['subnat_pop_denom'] = output.groupby(group_cols).transform(sum).population

output['subnat_pop_weight'] = [(i/j) if j!=0.0 else 1 for (i,j) in zip(output.population,output.subnat_pop_denom)]

output.value_mean = output.value_mean * output.subnat_pop_weight

output = output[group_cols + ['value_mean','lower','upper']].groupby(group_cols).sum()
# Out:
#                                                                                                       value_mean  \
# location_id location_name sub_population            vehicle     metric mass_unit time_unit pop_denom
# 163         India         total population          rice        mean   g         day       capita     282.770000
#                                                     salt        mean   g         day       consumers    9.500000
#                                                     wheat flour mean   g         day       capita     169.620000
# 179         Ethiopia      total population          maize flour mean   g         day       capita     113.840000
#                                                     salt        mean   g         day       capita       5.800000
#                                                     wheat flour mean   g         day       capita      97.640000
# 214         Nigeria       total population          maize flour mean   g         day       capita      95.100000
#                                                     salt        mean   g         day       consumers    7.200000
#                                                     wheat flour mean   g         day       capita      49.150000
#                           women of reproductive age bouillon    mean   g         day       consumers    2.668675
#                                                     rice        mean   g         day       consumers   91.367479
#
#                                                                                                           lower  \
# location_id location_name sub_population            vehicle     metric mass_unit time_unit pop_denom
# 163         India         total population          rice        mean   g         day       capita     72.457030
#                                                     salt        mean   g         day       consumers   7.023049
#                                                     wheat flour mean   g         day       capita      0.000000
# 179         Ethiopia      total population          maize flour mean   g         day       capita     17.713322
#                                                     salt        mean   g         day       capita      4.287756
#                                                     wheat flour mean   g         day       capita      0.000000
# 214         Nigeria       total population          maize flour mean   g         day       capita     14.797408
#                                                     salt        mean   g         day       consumers   5.322732
#                                                     wheat flour mean   g         day       capita      0.000000
#                           women of reproductive age bouillon    mean   g         day       consumers   3.089392
#                                                     rice        mean   g         day       consumers  45.354508
#
#                                                                                                            upper
# location_id location_name sub_population            vehicle     metric mass_unit time_unit pop_denom
# 163         India         total population          rice        mean   g         day       capita     493.082970
#                                                     salt        mean   g         day       consumers   11.976951
#                                                     wheat flour mean   g         day       capita     371.917789
# 179         Ethiopia      total population          maize flour mean   g         day       capita     209.966678
#                                                     salt        mean   g         day       capita       7.312244
#                                                     wheat flour mean   g         day       capita     214.090631
# 214         Nigeria       total population          maize flour mean   g         day       capita     175.402592
#                                                     salt        mean   g         day       consumers    9.077268
#                                                     wheat flour mean   g         day       capita     107.768891
#                           women of reproductive age bouillon    mean   g         day       consumers    6.910608
#                                                     rice        mean   g         day       consumers  308.645492

# %%
output
# Out:
#                                                                                                       value_mean  \
# location_id location_name sub_population            vehicle     metric mass_unit time_unit pop_denom
# 163         India         total population          rice        mean   g         day       capita     282.770000
#                                                     salt        mean   g         day       consumers    9.500000
#                                                     wheat flour mean   g         day       capita     169.620000
# 179         Ethiopia      total population          maize flour mean   g         day       capita     113.840000
#                                                     salt        mean   g         day       capita       5.800000
#                                                     wheat flour mean   g         day       capita      97.640000
# 214         Nigeria       total population          maize flour mean   g         day       capita      95.100000
#                                                     salt        mean   g         day       consumers    7.200000
#                                                     wheat flour mean   g         day       capita      49.150000
#                           women of reproductive age bouillon    mean   g         day       consumers    2.668675
#                                                     rice        mean   g         day       consumers   91.367479
#
#                                                                                                           lower  \
# location_id location_name sub_population            vehicle     metric mass_unit time_unit pop_denom
# 163         India         total population          rice        mean   g         day       capita     72.457030
#                                                     salt        mean   g         day       consumers   7.023049
#                                                     wheat flour mean   g         day       capita      0.000000
# 179         Ethiopia      total population          maize flour mean   g         day       capita     17.713322
#                                                     salt        mean   g         day       capita      4.287756
#                                                     wheat flour mean   g         day       capita      0.000000
# 214         Nigeria       total population          maize flour mean   g         day       capita     14.797408
#                                                     salt        mean   g         day       consumers   5.322732
#                                                     wheat flour mean   g         day       capita      0.000000
#                           women of reproductive age bouillon    mean   g         day       consumers   3.089392
#                                                     rice        mean   g         day       consumers  45.354508
#
#                                                                                                            upper
# location_id location_name sub_population            vehicle     metric mass_unit time_unit pop_denom
# 163         India         total population          rice        mean   g         day       capita     493.082970
#                                                     salt        mean   g         day       consumers   11.976951
#                                                     wheat flour mean   g         day       capita     371.917789
# 179         Ethiopia      total population          maize flour mean   g         day       capita     209.966678
#                                                     salt        mean   g         day       capita       7.312244
#                                                     wheat flour mean   g         day       capita     214.090631
# 214         Nigeria       total population          maize flour mean   g         day       capita     175.402592
#                                                     salt        mean   g         day       consumers    9.077268
#                                                     wheat flour mean   g         day       capita     107.768891
#                           women of reproductive age bouillon    mean   g         day       consumers    6.910608
#                                                     rice        mean   g         day       consumers  308.645492

# %% [markdown]
# ## check for missing values

# %%
## load legal combos
import pickle
data_prep_dir = '/ihme/homes/beatrixh/vivarium_data_analysis/pre_processing/lsff_project/data_prep/inputs/'

with open(data_prep_dir + 'lsff_vehicle_nutrient_pairs.pickle', 'rb') as handle:
    vehicle_nutrient_map = pickle.load(handle)
    
with open(data_prep_dir + 'lsff_country_vehicle_pairs.pickle', 'rb') as handle:
    country_vehicle_map = pickle.load(handle)
    
with open(data_prep_dir + 'lsff_vehicle_country_pairs.pickle', 'rb') as handle:
    vehicle_country_map = pickle.load(handle)

# %%
target_vehicles = [i for i in vehicle_nutrient_map.keys() if 'iron' in vehicle_nutrient_map[i]]

# %%
set([i for j in location_names for i in country_vehicle_map[j]])
# Out:
# {'bouillon', 'maize flour', 'oil', 'rice', 'salt', 'wheat flour'}

# %%
target = pd.DataFrame([(i,j) for i in location_names for j in country_vehicle_map[i] if j!='oil'], columns = ['location_name','vehicle'])

# %%
output.reset_index().merge(target, on = ['location_name','vehicle'], how = 'outer').set_index(group_cols)
# Out:
#                                                                                                       value_mean  \
# location_id location_name sub_population            vehicle     metric mass_unit time_unit pop_denom
# 163         India         total population          rice        mean   g         day       capita     282.770000
#                                                     salt        mean   g         day       consumers    9.500000
#                                                     wheat flour mean   g         day       capita     169.620000
# 179         Ethiopia      total population          maize flour mean   g         day       capita     113.840000
#                                                     salt        mean   g         day       capita       5.800000
#                                                     wheat flour mean   g         day       capita      97.640000
# 214         Nigeria       total population          maize flour mean   g         day       capita      95.100000
#                                                     salt        mean   g         day       consumers    7.200000
#                                                     wheat flour mean   g         day       capita      49.150000
#                           women of reproductive age bouillon    mean   g         day       consumers    2.668675
#                                                     rice        mean   g         day       consumers   91.367479
#
#                                                                                                           lower  \
# location_id location_name sub_population            vehicle     metric mass_unit time_unit pop_denom
# 163         India         total population          rice        mean   g         day       capita     72.457030
#                                                     salt        mean   g         day       consumers   7.023049
#                                                     wheat flour mean   g         day       capita      0.000000
# 179         Ethiopia      total population          maize flour mean   g         day       capita     17.713322
#                                                     salt        mean   g         day       capita      4.287756
#                                                     wheat flour mean   g         day       capita      0.000000
# 214         Nigeria       total population          maize flour mean   g         day       capita     14.797408
#                                                     salt        mean   g         day       consumers   5.322732
#                                                     wheat flour mean   g         day       capita      0.000000
#                           women of reproductive age bouillon    mean   g         day       consumers   3.089392
#                                                     rice        mean   g         day       consumers  45.354508
#
#                                                                                                            upper
# location_id location_name sub_population            vehicle     metric mass_unit time_unit pop_denom
# 163         India         total population          rice        mean   g         day       capita     493.082970
#                                                     salt        mean   g         day       consumers   11.976951
#                                                     wheat flour mean   g         day       capita     371.917789
# 179         Ethiopia      total population          maize flour mean   g         day       capita     209.966678
#                                                     salt        mean   g         day       capita       7.312244
#                                                     wheat flour mean   g         day       capita     214.090631
# 214         Nigeria       total population          maize flour mean   g         day       capita     175.402592
#                                                     salt        mean   g         day       consumers    9.077268
#                                                     wheat flour mean   g         day       capita     107.768891
#                           women of reproductive age bouillon    mean   g         day       consumers    6.910608
#                                                     rice        mean   g         day       consumers  308.645492

# %%
ls /ihme/homes/beatrixh/vivarium_data_analysis/pre_processing/lsff_project/data_prep/outputs
# Out:
# data_counts_full.csv
# data_counts_ideal_bins.csv
# data_counts_nutrient_na.csv
# data_summary_percent_of_population_eating_fortified_vehicle.csv
# data_summary_percent_of_population_eating_industrially_prod_vehicle.csv
# data_summary_percent_of_population_eating_vehicle.csv
# data_summary_percent_of_vehicle_fortified.csv
# data_summary_percent_of_vehicle_industrially_produced.csv
# lsff_data_estimated.csv
# lsff_data_stage0.csv
# LSFF_extraction_clean_data_rich_locations_01_11_2021.csv
# LSFF_extraction_clean_data_rich_locations_notes.xlsx*
# nigeria_ethiopia_india_coverage_data.csv
# plots/

# %%
save_path = '/ihme/homes/beatrixh/vivarium_data_analysis/pre_processing/lsff_project/data_prep/outputs/gday_nigeria_ethiopia_india_02_23_2021.csv'
output.to_csv(save_path)

# %% [markdown]
# ## compare CIs

# %%
gday['spread'] = gday.value_975_percentile - gday.value_025_percentile

# %%
gday['spread_over_mean'] = gday.spread / gday.value_mean

# %%
gday[['location_name','vehicle','value_mean','value_975_percentile','spread','spread_over_mean']].groupby('vehicle').mean().dropna()
# Out:
#              value_mean  value_975_percentile     spread  spread_over_mean
# vehicle
# bouillon       2.148718              3.285185   1.766667          0.902591
# wheat flour   73.033370            109.894444  47.944444          0.666020

# %%
gday[(gday.value_025_percentile.notna()) | (gday.value_975_percentile.notna())].vehicle.unique()
# Out:
# array(['wheat flour', 'bouillon'], dtype=object)

# %%
all_pop = get_population(age_group_id=22, 
                     location_id=list(gday.location_id.unique()),
                     year_id=2019,
                     sex_id=3,
                     gbd_round_id=6, 
                     decomp_step='step5')

# %%
all_pop = all_pop.rename(columns={'population':'pop_count'})[['location_id','pop_count']]

# %%
pop_counts = {i:j for (i,j) in zip(all_pop.location_id,all_pop.pop_count)}

# %%
gday['pop_count'] = gday.location_id.astype(int).map(pop_counts)

# %%
gday.loc[(gday.value_025_percentile.notna()) | (gday.value_975_percentile.notna()),'sd'] = (np.sqrt(gday.pop_count)*(gday.value_975_percentile - gday.value_025_percentile))/3.92

# %%
gday['cv'] = gday.sd / gday.value_mean

# %%
gday.loc[gday.cv.notna(),['location_name','vehicle','value_mean','value_975_percentile','sd','cv']].groupby('vehicle').mean()
# Out:
#              value_mean  value_975_percentile            sd           cv
# vehicle
# bouillon       2.111538              3.323077   2389.233212  1181.566148
# wheat flour   77.955556            109.894444  69754.107056   988.059275

# %%
gday

# %%
gday[(gday.value_025_percentile.notna()) | (gday.value_975_percentile.notna())]

# %%
gday.loc[gday.value_025_percentile=='na','value_025_percentile'] = np.nan
gday.value_025_percentile = gday.value_025_percentile.astype(float)

gday.loc[gday.value_975_percentile=='na','value_975_percentile'] = np.nan
gday.value_975_percentile = gday.value_975_percentile.astype(float)

# %%
lower_error = gday.lower - gday.value_025_percentile 
upper_error = gday.value_975_percentile - gday.upper

# %%
errors = pd.DataFrame({'lower':lower_error,'upper':upper_error,'value_mean':gday.value_mean})

# %%
plt.figure(figsize=(8,5))
plt.scatter(x = errors.value_mean, y = errors.lower, label = 'lower')
plt.scatter(x = errors.value_mean, y = errors.upper, label = 'upper')

plt.xlabel('mean_value', fontsize=15)
plt.ylabel('absolute error', fontsize=15)
plt.title('Absolute error in upper/lower estimation as a fn of mean val', fontsize=18)

plt.legend()
plt.show()

plt.figure(figsize=(8,5))
plt.scatter(x = errors.value_mean, y = errors.lower/errors.value_mean, label = 'lower')
plt.scatter(x = errors.value_mean, y = errors.upper/errors.value_mean, label = 'upper')

plt.xlabel('mean_value', fontsize=15)
plt.ylabel('relative error', fontsize=15)
plt.title('Relative error in upper/lower estimation as a fn of mean val', fontsize=18)

plt.legend()
plt.show()
