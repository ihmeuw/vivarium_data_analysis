# %%
from db_queries import get_model_results

# %%
vitA_df = get_model_results('epi', 2510, gbd_round_id=5, location_set_id=22, sex_id=[1,2])
vitA_df
# Out:
#          model_version_id  location_id  year_id  age_group_id  sex_id  \
# 0                  321155            1     1990             2       1
# 1                  321155            1     1990             3       1
# 2                  321155            1     1990             4       1
# 3                  321155            1     1990             5       1
# 4                  321155            1     1990             6       1
# ...                   ...          ...      ...           ...     ...
# 2839195            321155        53432     2017            30       2
# 2839196            321155        53432     2017            31       2
# 2839197            321155        53432     2017            32       2
# 2839198            321155        53432     2017           164       2
# 2839199            321155        53432     2017           235       2
#
#          measure_id    measure      mean     lower     upper
# 0                 6  incidence  0.271936  0.236371  0.310223
# ...

# %%
vitA_df.query('measure == "remission" and measure_id == 7')
# Out:
#          model_version_id  location_id  year_id  age_group_id  sex_id  \
# 2555280            321155            1     1990             2       1
# 2555281            321155            1     1990             3       1
# 2555282            321155            1     1990             4       1
# 2555283            321155            1     1990             5       1
# 2555284            321155            1     1990             6       1
# ...                   ...          ...      ...           ...     ...
# 2839195            321155        53432     2017            30       2
# 2839196            321155        53432     2017            31       2
# 2839197            321155        53432     2017            32       2
# 2839198            321155        53432     2017           164       2
# 2839199            321155        53432     2017           235       2
#
#          measure_id    measure      mean     lower     upper
# 2555280           7  remission  1.350602  1.048709  1.647343
# ...
