# %%
from vivarium import Artifact
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from db_queries import get_ids, get_outputs
import scipy.stats

# !whoami
# !date
# Out:
# alibow
# Thu Jun 18 13:40:17 PDT 2020

# %%
output_dirs = ['/share/costeffectiveness/results/vivarium_conic_lsff/00_bugfix/v7.0_prelim_nigeria/count_data/']

locations = ['Nigeria']

# %%
# available data frames

# births
# births_with_ntd
# birth_weight
# deaths
# gestational_age
# person_time
# population
# state_person_time
# transition_count
# ylds
# ylls

# %%
bw = pd.read_hdf(output_dirs[0] + 'birth_weight.hdf')
bw.head()
# Out:
#                                              measure  input_draw  \
# 0  birth_weight_mean_in_2020_among_female_iron_fo...         357
# 1  birth_weight_mean_in_2020_among_female_iron_fo...         357
# 2  birth_weight_mean_in_2020_among_female_iron_fo...         357
# 3  birth_weight_mean_in_2020_among_female_iron_fo...         357
# 4  birth_weight_mean_in_2020_among_female_iron_fo...         602
#
#                             scenario        value
# 0                           baseline  3244.991958
# 1  folic_acid_fortification_scale_up  3244.991958
# 2        iron_fortification_scale_up  3244.991958
# 3   vitamin_a_fortification_scale_up  3244.991958
# 4                           baseline  3111.953987

# %%
np.unique(bw['measure'])
# Out:
# array(['birth_weight_mean_in_2020_among_female_iron_fortification_group_covered',
#        'birth_weight_mean_in_2020_among_female_iron_fortification_group_uncovered',
#        'birth_weight_mean_in_2020_among_male_iron_fortification_group_covered',
#        'birth_weight_mean_in_2020_among_male_iron_fortification_group_uncovered',
#        'birth_weight_mean_in_2021_among_female_iron_fortification_group_covered',
#        'birth_weight_mean_in_2021_among_female_iron_fortification_group_uncovered',
#        'birth_weight_mean_in_2021_among_male_iron_fortification_group_covered',
#        'birth_weight_mean_in_2021_among_male_iron_fortification_group_uncovered',
#        'birth_weight_mean_in_2022_among_female_iron_fortification_group_covered',
#        'birth_weight_mean_in_2022_among_female_iron_fortification_group_uncovered',
#        'birth_weight_mean_in_2022_among_male_iron_fortification_group_covered',
#        'birth_weight_mean_in_2022_among_male_iron_fortification_group_uncovered',
#        'birth_weight_mean_in_2023_among_female_iron_fortification_group_covered',
#        'birth_weight_mean_in_2023_among_female_iron_fortification_group_uncovered',
#        'birth_weight_mean_in_2023_among_male_iron_fortification_group_covered',
#        'birth_weight_mean_in_2023_among_male_iron_fortification_group_uncovered',
#        'birth_weight_mean_in_2024_among_female_iron_fortification_group_covered',
#        'birth_weight_mean_in_2024_among_female_iron_fortification_group_uncovered',
#        'birth_weight_mean_in_2024_among_male_iron_fortification_group_covered',
#        'birth_weight_mean_in_2024_among_male_iron_fortification_group_uncovered',
#        'birth_weight_mean_in_2025_among_female_iron_fortification_group_covered',
#        'birth_weight_mean_in_2025_among_female_iron_fortification_group_uncovered',
#        'birth_weight_mean_in_2025_among_male_iron_fortification_group_covered',
#        'birth_weight_mean_in_2025_among_male_iron_fortification_group_uncovered',
#        'birth_weight_sd_in_2020_among_female_iron_fortification_group_covered',
#        'birth_weight_sd_in_2020_among_female_iron_fortification_group_uncovered',
#        'birth_weight_sd_in_2020_among_male_iron_fortification_group_covered',
#        'birth_weight_sd_in_2020_among_male_iron_fortification_group_uncovered',
#        'birth_weight_sd_in_2021_among_female_iron_fortification_group_covered',
#        'birth_weight_sd_in_2021_among_female_iron_fortification_group_uncovered',
#        'birth_weight_sd_in_2021_among_male_iron_fortification_group_covered',
#        'birth_weight_sd_in_2021_among_male_iron_fortification_group_uncovered',
#        'birth_weight_sd_in_2022_among_female_iron_fortification_group_covered',
#        'birth_weight_sd_in_2022_among_female_iron_fortification_group_uncovered',
#        'birth_weight_sd_in_2022_among_male_iron_fortification_group_covered',
#        'birth_weight_sd_in_2022_among_male_iron_fortification_group_uncovered',
#        'birth_weight_sd_in_2023_among_female_iron_fortification_group_covered',
#        'birth_weight_sd_in_2023_among_female_iron_fortification_group_uncovered',
#        'birth_weight_sd_in_2023_among_male_iron_fortification_group_covered',
#        'birth_weight_sd_in_2023_among_male_iron_fortification_group_uncovered',
#        'birth_weight_sd_in_2024_among_female_iron_fortification_group_covered',
#        'birth_weight_sd_in_2024_among_female_iron_fortification_group_uncovered',
#        'birth_weight_sd_in_2024_among_male_iron_fortification_group_covered',
#        'birth_weight_sd_in_2024_among_male_iron_fortification_group_uncovered',
#        'birth_weight_sd_in_2025_among_female_iron_fortification_group_covered',
#        'birth_weight_sd_in_2025_among_female_iron_fortification_group_uncovered',
#        'birth_weight_sd_in_2025_among_male_iron_fortification_group_covered',
#        'birth_weight_sd_in_2025_among_male_iron_fortification_group_uncovered'],
#       dtype=object)

# %%
bw_mean = bw.groupby(['measure','scenario']).describe()
bw_mean
# Out:
#                                                                                      input_draw  \
#                                                                                           count
# measure                                            scenario
# birth_weight_mean_in_2020_among_female_iron_for... baseline                                 2.0
#                                                    folic_acid_fortification_scale_up        2.0
#                                                    iron_fortification_scale_up              2.0
#                                                    vitamin_a_fortification_scale_up         2.0
# birth_weight_mean_in_2020_among_female_iron_for... baseline                                 2.0
#                                                    folic_acid_fortification_scale_up        2.0
#                                                    iron_fortification_scale_up              2.0
#                                                    vitamin_a_fortification_scale_up         2.0
# birth_weight_mean_in_2020_among_male_iron_forti... baseline                                 2.0
#                                                    folic_acid_fortification_scale_up        2.0
#                                                    iron_fortification_scale_up              2.0
#                                                    vitamin_a_fortification_scale_up         2.0
# birth_weight_mean_in_2020_among_male_iron_forti... baseline                                 2.0
#                                                    folic_acid_fortification_scale_up        2.0
#                                                    iron_fortification_scale_up              2.0
#                                                    vitamin_a_fortification_scale_up         2.0
# birth_weight_mean_in_2021_among_female_iron_for... baseline                                 2.0
#                                                    folic_acid_fortification_scale_up        2.0
#                                                    iron_fortification_scale_up              2.0
#                                                    vitamin_a_fortification_scale_up         2.0
# birth_weight_mean_in_2021_among_female_iron_for... baseline                                 2.0
#                                                    folic_acid_fortification_scale_up        2.0
#                                                    iron_fortification_scale_up              2.0
#                                                    vitamin_a_fortification_scale_up         2.0
# birth_weight_mean_in_2021_among_male_iron_forti... baseline                                 2.0
#                                                    folic_acid_fortification_scale_up        2.0
#                                                    iron_fortification_scale_up              2.0
#                                                    vitamin_a_fortification_scale_up         2.0
# birth_weight_mean_in_2021_among_male_iron_forti... baseline                                 2.0
#                                                    folic_acid_fortification_scale_up        2.0
# ...                                                                                         ...
# birth_weight_sd_in_2024_among_female_iron_forti... iron_fortification_scale_up              2.0
#                                                    vitamin_a_fortification_scale_up         2.0
# birth_weight_sd_in_2024_among_female_iron_forti... baseline                                 2.0
#                                                    folic_acid_fortification_scale_up        2.0
#                                                    iron_fortification_scale_up              2.0
#                                                    vitamin_a_fortification_scale_up         2.0
# birth_weight_sd_in_2024_among_male_iron_fortifi... baseline                                 2.0
#                                                    folic_acid_fortification_scale_up        2.0
#                                                    iron_fortification_scale_up              2.0
#                                                    vitamin_a_fortification_scale_up         2.0
# birth_weight_sd_in_2024_among_male_iron_fortifi... baseline                                 2.0
#                                                    folic_acid_fortification_scale_up        2.0
#                                                    iron_fortification_scale_up              2.0
#                                                    vitamin_a_fortification_scale_up         2.0
# birth_weight_sd_in_2025_among_female_iron_forti... baseline                                 2.0
#                                                    folic_acid_fortification_scale_up        2.0
#                                                    iron_fortification_scale_up              2.0
#                                                    vitamin_a_fortification_scale_up         2.0
# birth_weight_sd_in_2025_among_female_iron_forti... baseline                                 2.0
#                                                    folic_acid_fortification_scale_up        2.0
#                                                    iron_fortification_scale_up              2.0
#                                                    vitamin_a_fortification_scale_up         2.0
# birth_weight_sd_in_2025_among_male_iron_fortifi... baseline                                 2.0
#                                                    folic_acid_fortification_scale_up        2.0
#                                                    iron_fortification_scale_up              2.0
#                                                    vitamin_a_fortification_scale_up         2.0
# birth_weight_sd_in_2025_among_male_iron_fortifi... baseline                                 2.0
#                                                    folic_acid_fortification_scale_up        2.0
#                                                    iron_fortification_scale_up              2.0
#                                                    vitamin_a_fortification_scale_up         2.0
#
#                                                                                              \
#                                                                                        mean
# measure                                            scenario
# birth_weight_mean_in_2020_among_female_iron_for... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_mean_in_2020_among_female_iron_for... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_mean_in_2020_among_male_iron_forti... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_mean_in_2020_among_male_iron_forti... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_mean_in_2021_among_female_iron_for... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_mean_in_2021_among_female_iron_for... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_mean_in_2021_among_male_iron_forti... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_mean_in_2021_among_male_iron_forti... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
# ...                                                                                     ...
# birth_weight_sd_in_2024_among_female_iron_forti... iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_sd_in_2024_among_female_iron_forti... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_sd_in_2024_among_male_iron_fortifi... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_sd_in_2024_among_male_iron_fortifi... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_sd_in_2025_among_female_iron_forti... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_sd_in_2025_among_female_iron_forti... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_sd_in_2025_among_male_iron_fortifi... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_sd_in_2025_among_male_iron_fortifi... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
#
#                                                                                                   \
#                                                                                              std
# measure                                            scenario
# birth_weight_mean_in_2020_among_female_iron_for... baseline                           173.241161
#                                                    folic_acid_fortification_scale_up  173.241161
#                                                    iron_fortification_scale_up        173.241161
#                                                    vitamin_a_fortification_scale_up   173.241161
# birth_weight_mean_in_2020_among_female_iron_for... baseline                           173.241161
#                                                    folic_acid_fortification_scale_up  173.241161
#                                                    iron_fortification_scale_up        173.241161
#                                                    vitamin_a_fortification_scale_up   173.241161
# birth_weight_mean_in_2020_among_male_iron_forti... baseline                           173.241161
#                                                    folic_acid_fortification_scale_up  173.241161
#                                                    iron_fortification_scale_up        173.241161
#                                                    vitamin_a_fortification_scale_up   173.241161
# birth_weight_mean_in_2020_among_male_iron_forti... baseline                           173.241161
#                                                    folic_acid_fortification_scale_up  173.241161
#                                                    iron_fortification_scale_up        173.241161
#                                                    vitamin_a_fortification_scale_up   173.241161
# birth_weight_mean_in_2021_among_female_iron_for... baseline                           173.241161
#                                                    folic_acid_fortification_scale_up  173.241161
#                                                    iron_fortification_scale_up        173.241161
#                                                    vitamin_a_fortification_scale_up   173.241161
# birth_weight_mean_in_2021_among_female_iron_for... baseline                           173.241161
#                                                    folic_acid_fortification_scale_up  173.241161
#                                                    iron_fortification_scale_up        173.241161
#                                                    vitamin_a_fortification_scale_up   173.241161
# birth_weight_mean_in_2021_among_male_iron_forti... baseline                           173.241161
#                                                    folic_acid_fortification_scale_up  173.241161
#                                                    iron_fortification_scale_up        173.241161
#                                                    vitamin_a_fortification_scale_up   173.241161
# birth_weight_mean_in_2021_among_male_iron_forti... baseline                           173.241161
#                                                    folic_acid_fortification_scale_up  173.241161
# ...                                                                                          ...
# birth_weight_sd_in_2024_among_female_iron_forti... iron_fortification_scale_up        173.241161
#                                                    vitamin_a_fortification_scale_up   173.241161
# birth_weight_sd_in_2024_among_female_iron_forti... baseline                           173.241161
#                                                    folic_acid_fortification_scale_up  173.241161
#                                                    iron_fortification_scale_up        173.241161
#                                                    vitamin_a_fortification_scale_up   173.241161
# birth_weight_sd_in_2024_among_male_iron_fortifi... baseline                           173.241161
#                                                    folic_acid_fortification_scale_up  173.241161
#                                                    iron_fortification_scale_up        173.241161
#                                                    vitamin_a_fortification_scale_up   173.241161
# birth_weight_sd_in_2024_among_male_iron_fortifi... baseline                           173.241161
#                                                    folic_acid_fortification_scale_up  173.241161
#                                                    iron_fortification_scale_up        173.241161
#                                                    vitamin_a_fortification_scale_up   173.241161
# birth_weight_sd_in_2025_among_female_iron_forti... baseline                           173.241161
#                                                    folic_acid_fortification_scale_up  173.241161
#                                                    iron_fortification_scale_up        173.241161
#                                                    vitamin_a_fortification_scale_up   173.241161
# birth_weight_sd_in_2025_among_female_iron_forti... baseline                           173.241161
#                                                    folic_acid_fortification_scale_up  173.241161
#                                                    iron_fortification_scale_up        173.241161
#                                                    vitamin_a_fortification_scale_up   173.241161
# birth_weight_sd_in_2025_among_male_iron_fortifi... baseline                           173.241161
#                                                    folic_acid_fortification_scale_up  173.241161
#                                                    iron_fortification_scale_up        173.241161
#                                                    vitamin_a_fortification_scale_up   173.241161
# birth_weight_sd_in_2025_among_male_iron_fortifi... baseline                           173.241161
#                                                    folic_acid_fortification_scale_up  173.241161
#                                                    iron_fortification_scale_up        173.241161
#                                                    vitamin_a_fortification_scale_up   173.241161
#
#                                                                                              \
#                                                                                         min
# measure                                            scenario
# birth_weight_mean_in_2020_among_female_iron_for... baseline                           357.0
#                                                    folic_acid_fortification_scale_up  357.0
#                                                    iron_fortification_scale_up        357.0
#                                                    vitamin_a_fortification_scale_up   357.0
# birth_weight_mean_in_2020_among_female_iron_for... baseline                           357.0
#                                                    folic_acid_fortification_scale_up  357.0
#                                                    iron_fortification_scale_up        357.0
#                                                    vitamin_a_fortification_scale_up   357.0
# birth_weight_mean_in_2020_among_male_iron_forti... baseline                           357.0
#                                                    folic_acid_fortification_scale_up  357.0
#                                                    iron_fortification_scale_up        357.0
#                                                    vitamin_a_fortification_scale_up   357.0
# birth_weight_mean_in_2020_among_male_iron_forti... baseline                           357.0
#                                                    folic_acid_fortification_scale_up  357.0
#                                                    iron_fortification_scale_up        357.0
#                                                    vitamin_a_fortification_scale_up   357.0
# birth_weight_mean_in_2021_among_female_iron_for... baseline                           357.0
#                                                    folic_acid_fortification_scale_up  357.0
#                                                    iron_fortification_scale_up        357.0
#                                                    vitamin_a_fortification_scale_up   357.0
# birth_weight_mean_in_2021_among_female_iron_for... baseline                           357.0
#                                                    folic_acid_fortification_scale_up  357.0
#                                                    iron_fortification_scale_up        357.0
#                                                    vitamin_a_fortification_scale_up   357.0
# birth_weight_mean_in_2021_among_male_iron_forti... baseline                           357.0
#                                                    folic_acid_fortification_scale_up  357.0
#                                                    iron_fortification_scale_up        357.0
#                                                    vitamin_a_fortification_scale_up   357.0
# birth_weight_mean_in_2021_among_male_iron_forti... baseline                           357.0
#                                                    folic_acid_fortification_scale_up  357.0
# ...                                                                                     ...
# birth_weight_sd_in_2024_among_female_iron_forti... iron_fortification_scale_up        357.0
#                                                    vitamin_a_fortification_scale_up   357.0
# birth_weight_sd_in_2024_among_female_iron_forti... baseline                           357.0
#                                                    folic_acid_fortification_scale_up  357.0
#                                                    iron_fortification_scale_up        357.0
#                                                    vitamin_a_fortification_scale_up   357.0
# birth_weight_sd_in_2024_among_male_iron_fortifi... baseline                           357.0
#                                                    folic_acid_fortification_scale_up  357.0
#                                                    iron_fortification_scale_up        357.0
#                                                    vitamin_a_fortification_scale_up   357.0
# birth_weight_sd_in_2024_among_male_iron_fortifi... baseline                           357.0
#                                                    folic_acid_fortification_scale_up  357.0
#                                                    iron_fortification_scale_up        357.0
#                                                    vitamin_a_fortification_scale_up   357.0
# birth_weight_sd_in_2025_among_female_iron_forti... baseline                           357.0
#                                                    folic_acid_fortification_scale_up  357.0
#                                                    iron_fortification_scale_up        357.0
#                                                    vitamin_a_fortification_scale_up   357.0
# birth_weight_sd_in_2025_among_female_iron_forti... baseline                           357.0
#                                                    folic_acid_fortification_scale_up  357.0
#                                                    iron_fortification_scale_up        357.0
#                                                    vitamin_a_fortification_scale_up   357.0
# birth_weight_sd_in_2025_among_male_iron_fortifi... baseline                           357.0
#                                                    folic_acid_fortification_scale_up  357.0
#                                                    iron_fortification_scale_up        357.0
#                                                    vitamin_a_fortification_scale_up   357.0
# birth_weight_sd_in_2025_among_male_iron_fortifi... baseline                           357.0
#                                                    folic_acid_fortification_scale_up  357.0
#                                                    iron_fortification_scale_up        357.0
#                                                    vitamin_a_fortification_scale_up   357.0
#
#                                                                                               \
#                                                                                          25%
# measure                                            scenario
# birth_weight_mean_in_2020_among_female_iron_for... baseline                           418.25
#                                                    folic_acid_fortification_scale_up  418.25
#                                                    iron_fortification_scale_up        418.25
#                                                    vitamin_a_fortification_scale_up   418.25
# birth_weight_mean_in_2020_among_female_iron_for... baseline                           418.25
#                                                    folic_acid_fortification_scale_up  418.25
#                                                    iron_fortification_scale_up        418.25
#                                                    vitamin_a_fortification_scale_up   418.25
# birth_weight_mean_in_2020_among_male_iron_forti... baseline                           418.25
#                                                    folic_acid_fortification_scale_up  418.25
#                                                    iron_fortification_scale_up        418.25
#                                                    vitamin_a_fortification_scale_up   418.25
# birth_weight_mean_in_2020_among_male_iron_forti... baseline                           418.25
#                                                    folic_acid_fortification_scale_up  418.25
#                                                    iron_fortification_scale_up        418.25
#                                                    vitamin_a_fortification_scale_up   418.25
# birth_weight_mean_in_2021_among_female_iron_for... baseline                           418.25
#                                                    folic_acid_fortification_scale_up  418.25
#                                                    iron_fortification_scale_up        418.25
#                                                    vitamin_a_fortification_scale_up   418.25
# birth_weight_mean_in_2021_among_female_iron_for... baseline                           418.25
#                                                    folic_acid_fortification_scale_up  418.25
#                                                    iron_fortification_scale_up        418.25
#                                                    vitamin_a_fortification_scale_up   418.25
# birth_weight_mean_in_2021_among_male_iron_forti... baseline                           418.25
#                                                    folic_acid_fortification_scale_up  418.25
#                                                    iron_fortification_scale_up        418.25
#                                                    vitamin_a_fortification_scale_up   418.25
# birth_weight_mean_in_2021_among_male_iron_forti... baseline                           418.25
#                                                    folic_acid_fortification_scale_up  418.25
# ...                                                                                      ...
# birth_weight_sd_in_2024_among_female_iron_forti... iron_fortification_scale_up        418.25
#                                                    vitamin_a_fortification_scale_up   418.25
# birth_weight_sd_in_2024_among_female_iron_forti... baseline                           418.25
#                                                    folic_acid_fortification_scale_up  418.25
#                                                    iron_fortification_scale_up        418.25
#                                                    vitamin_a_fortification_scale_up   418.25
# birth_weight_sd_in_2024_among_male_iron_fortifi... baseline                           418.25
#                                                    folic_acid_fortification_scale_up  418.25
#                                                    iron_fortification_scale_up        418.25
#                                                    vitamin_a_fortification_scale_up   418.25
# birth_weight_sd_in_2024_among_male_iron_fortifi... baseline                           418.25
#                                                    folic_acid_fortification_scale_up  418.25
#                                                    iron_fortification_scale_up        418.25
#                                                    vitamin_a_fortification_scale_up   418.25
# birth_weight_sd_in_2025_among_female_iron_forti... baseline                           418.25
#                                                    folic_acid_fortification_scale_up  418.25
#                                                    iron_fortification_scale_up        418.25
#                                                    vitamin_a_fortification_scale_up   418.25
# birth_weight_sd_in_2025_among_female_iron_forti... baseline                           418.25
#                                                    folic_acid_fortification_scale_up  418.25
#                                                    iron_fortification_scale_up        418.25
#                                                    vitamin_a_fortification_scale_up   418.25
# birth_weight_sd_in_2025_among_male_iron_fortifi... baseline                           418.25
#                                                    folic_acid_fortification_scale_up  418.25
#                                                    iron_fortification_scale_up        418.25
#                                                    vitamin_a_fortification_scale_up   418.25
# birth_weight_sd_in_2025_among_male_iron_fortifi... baseline                           418.25
#                                                    folic_acid_fortification_scale_up  418.25
#                                                    iron_fortification_scale_up        418.25
#                                                    vitamin_a_fortification_scale_up   418.25
#
#                                                                                              \
#                                                                                         50%
# measure                                            scenario
# birth_weight_mean_in_2020_among_female_iron_for... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_mean_in_2020_among_female_iron_for... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_mean_in_2020_among_male_iron_forti... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_mean_in_2020_among_male_iron_forti... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_mean_in_2021_among_female_iron_for... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_mean_in_2021_among_female_iron_for... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_mean_in_2021_among_male_iron_forti... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_mean_in_2021_among_male_iron_forti... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
# ...                                                                                     ...
# birth_weight_sd_in_2024_among_female_iron_forti... iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_sd_in_2024_among_female_iron_forti... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_sd_in_2024_among_male_iron_fortifi... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_sd_in_2024_among_male_iron_fortifi... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_sd_in_2025_among_female_iron_forti... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_sd_in_2025_among_female_iron_forti... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_sd_in_2025_among_male_iron_fortifi... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
# birth_weight_sd_in_2025_among_male_iron_fortifi... baseline                           479.5
#                                                    folic_acid_fortification_scale_up  479.5
#                                                    iron_fortification_scale_up        479.5
#                                                    vitamin_a_fortification_scale_up   479.5
#
#                                                                                               \
#                                                                                          75%
# measure                                            scenario
# birth_weight_mean_in_2020_among_female_iron_for... baseline                           540.75
#                                                    folic_acid_fortification_scale_up  540.75
#                                                    iron_fortification_scale_up        540.75
#                                                    vitamin_a_fortification_scale_up   540.75
# birth_weight_mean_in_2020_among_female_iron_for... baseline                           540.75
#                                                    folic_acid_fortification_scale_up  540.75
#                                                    iron_fortification_scale_up        540.75
#                                                    vitamin_a_fortification_scale_up   540.75
# birth_weight_mean_in_2020_among_male_iron_forti... baseline                           540.75
#                                                    folic_acid_fortification_scale_up  540.75
#                                                    iron_fortification_scale_up        540.75
#                                                    vitamin_a_fortification_scale_up   540.75
# birth_weight_mean_in_2020_among_male_iron_forti... baseline                           540.75
#                                                    folic_acid_fortification_scale_up  540.75
#                                                    iron_fortification_scale_up        540.75
#                                                    vitamin_a_fortification_scale_up   540.75
# birth_weight_mean_in_2021_among_female_iron_for... baseline                           540.75
#                                                    folic_acid_fortification_scale_up  540.75
#                                                    iron_fortification_scale_up        540.75
#                                                    vitamin_a_fortification_scale_up   540.75
# birth_weight_mean_in_2021_among_female_iron_for... baseline                           540.75
#                                                    folic_acid_fortification_scale_up  540.75
#                                                    iron_fortification_scale_up        540.75
#                                                    vitamin_a_fortification_scale_up   540.75
# birth_weight_mean_in_2021_among_male_iron_forti... baseline                           540.75
#                                                    folic_acid_fortification_scale_up  540.75
#                                                    iron_fortification_scale_up        540.75
#                                                    vitamin_a_fortification_scale_up   540.75
# birth_weight_mean_in_2021_among_male_iron_forti... baseline                           540.75
#                                                    folic_acid_fortification_scale_up  540.75
# ...                                                                                      ...
# birth_weight_sd_in_2024_among_female_iron_forti... iron_fortification_scale_up        540.75
#                                                    vitamin_a_fortification_scale_up   540.75
# birth_weight_sd_in_2024_among_female_iron_forti... baseline                           540.75
#                                                    folic_acid_fortification_scale_up  540.75
#                                                    iron_fortification_scale_up        540.75
#                                                    vitamin_a_fortification_scale_up   540.75
# birth_weight_sd_in_2024_among_male_iron_fortifi... baseline                           540.75
#                                                    folic_acid_fortification_scale_up  540.75
#                                                    iron_fortification_scale_up        540.75
#                                                    vitamin_a_fortification_scale_up   540.75
# birth_weight_sd_in_2024_among_male_iron_fortifi... baseline                           540.75
#                                                    folic_acid_fortification_scale_up  540.75
#                                                    iron_fortification_scale_up        540.75
#                                                    vitamin_a_fortification_scale_up   540.75
# birth_weight_sd_in_2025_among_female_iron_forti... baseline                           540.75
#                                                    folic_acid_fortification_scale_up  540.75
#                                                    iron_fortification_scale_up        540.75
#                                                    vitamin_a_fortification_scale_up   540.75
# birth_weight_sd_in_2025_among_female_iron_forti... baseline                           540.75
#                                                    folic_acid_fortification_scale_up  540.75
#                                                    iron_fortification_scale_up        540.75
#                                                    vitamin_a_fortification_scale_up   540.75
# birth_weight_sd_in_2025_among_male_iron_fortifi... baseline                           540.75
#                                                    folic_acid_fortification_scale_up  540.75
#                                                    iron_fortification_scale_up        540.75
#                                                    vitamin_a_fortification_scale_up   540.75
# birth_weight_sd_in_2025_among_male_iron_fortifi... baseline                           540.75
#                                                    folic_acid_fortification_scale_up  540.75
#                                                    iron_fortification_scale_up        540.75
#                                                    vitamin_a_fortification_scale_up   540.75
#
#                                                                                              \
#                                                                                         max
# measure                                            scenario
# birth_weight_mean_in_2020_among_female_iron_for... baseline                           602.0
#                                                    folic_acid_fortification_scale_up  602.0
#                                                    iron_fortification_scale_up        602.0
#                                                    vitamin_a_fortification_scale_up   602.0
# birth_weight_mean_in_2020_among_female_iron_for... baseline                           602.0
#                                                    folic_acid_fortification_scale_up  602.0
#                                                    iron_fortification_scale_up        602.0
#                                                    vitamin_a_fortification_scale_up   602.0
# birth_weight_mean_in_2020_among_male_iron_forti... baseline                           602.0
#                                                    folic_acid_fortification_scale_up  602.0
#                                                    iron_fortification_scale_up        602.0
#                                                    vitamin_a_fortification_scale_up   602.0
# birth_weight_mean_in_2020_among_male_iron_forti... baseline                           602.0
#                                                    folic_acid_fortification_scale_up  602.0
#                                                    iron_fortification_scale_up        602.0
#                                                    vitamin_a_fortification_scale_up   602.0
# birth_weight_mean_in_2021_among_female_iron_for... baseline                           602.0
#                                                    folic_acid_fortification_scale_up  602.0
#                                                    iron_fortification_scale_up        602.0
#                                                    vitamin_a_fortification_scale_up   602.0
# birth_weight_mean_in_2021_among_female_iron_for... baseline                           602.0
#                                                    folic_acid_fortification_scale_up  602.0
#                                                    iron_fortification_scale_up        602.0
#                                                    vitamin_a_fortification_scale_up   602.0
# birth_weight_mean_in_2021_among_male_iron_forti... baseline                           602.0
#                                                    folic_acid_fortification_scale_up  602.0
#                                                    iron_fortification_scale_up        602.0
#                                                    vitamin_a_fortification_scale_up   602.0
# birth_weight_mean_in_2021_among_male_iron_forti... baseline                           602.0
#                                                    folic_acid_fortification_scale_up  602.0
# ...                                                                                     ...
# birth_weight_sd_in_2024_among_female_iron_forti... iron_fortification_scale_up        602.0
#                                                    vitamin_a_fortification_scale_up   602.0
# birth_weight_sd_in_2024_among_female_iron_forti... baseline                           602.0
#                                                    folic_acid_fortification_scale_up  602.0
#                                                    iron_fortification_scale_up        602.0
#                                                    vitamin_a_fortification_scale_up   602.0
# birth_weight_sd_in_2024_among_male_iron_fortifi... baseline                           602.0
#                                                    folic_acid_fortification_scale_up  602.0
#                                                    iron_fortification_scale_up        602.0
#                                                    vitamin_a_fortification_scale_up   602.0
# birth_weight_sd_in_2024_among_male_iron_fortifi... baseline                           602.0
#                                                    folic_acid_fortification_scale_up  602.0
#                                                    iron_fortification_scale_up        602.0
#                                                    vitamin_a_fortification_scale_up   602.0
# birth_weight_sd_in_2025_among_female_iron_forti... baseline                           602.0
# ...
# birth_weight_sd_in_2024_among_female_iron_forti... iron_fortification_scale_up         633.430058
#                                                    vitamin_a_fortification_scale_up    633.430058
# birth_weight_sd_in_2024_among_female_iron_forti... baseline                            631.245646
#                                                    folic_acid_fortification_scale_up   631.245646
#                                                    iron_fortification_scale_up         631.245646
#                                                    vitamin_a_fortification_scale_up    631.245646
# birth_weight_sd_in_2024_among_male_iron_fortifi... baseline                            617.516728
#                                                    folic_acid_fortification_scale_up   617.516728
#                                                    iron_fortification_scale_up         617.516728
#                                                    vitamin_a_fortification_scale_up    617.516728
# birth_weight_sd_in_2024_among_male_iron_fortifi... baseline                            629.562784
#                                                    folic_acid_fortification_scale_up   629.562784
#                                                    iron_fortification_scale_up         629.562784
#                                                    vitamin_a_fortification_scale_up    629.562784
# birth_weight_sd_in_2025_among_female_iron_forti... baseline                            628.402706
#                                                    folic_acid_fortification_scale_up   628.402706
#                                                    iron_fortification_scale_up         628.402706
#                                                    vitamin_a_fortification_scale_up    628.402706
# birth_weight_sd_in_2025_among_female_iron_forti... baseline                            634.807099
#                                                    folic_acid_fortification_scale_up   634.807099
#                                                    iron_fortification_scale_up         634.807099
#                                                    vitamin_a_fortification_scale_up    634.807099
# birth_weight_sd_in_2025_among_male_iron_fortifi... baseline                            614.300386
#                                                    folic_acid_fortification_scale_up   614.300386
#                                                    iron_fortification_scale_up         614.300386
#                                                    vitamin_a_fortification_scale_up    614.300386
# birth_weight_sd_in_2025_among_male_iron_fortifi... baseline                            614.312061
#                                                    folic_acid_fortification_scale_up   614.312061
#                                                    iron_fortification_scale_up         614.312061
#                                                    vitamin_a_fortification_scale_up    614.312061
#
#                                                                                                    \
#                                                                                               75%
# measure                                            scenario
# birth_weight_mean_in_2020_among_female_iron_for... baseline                           3211.732465
#                                                    folic_acid_fortification_scale_up  3211.732465
#                                                    iron_fortification_scale_up        3211.732465
#                                                    vitamin_a_fortification_scale_up   3211.732465
# birth_weight_mean_in_2020_among_female_iron_for... baseline                           3188.657441
#                                                    folic_acid_fortification_scale_up  3188.657441
#                                                    iron_fortification_scale_up        3188.657441
#                                                    vitamin_a_fortification_scale_up   3188.657441
# birth_weight_mean_in_2020_among_male_iron_forti... baseline                           3187.938612
#                                                    folic_acid_fortification_scale_up  3187.938612
#                                                    iron_fortification_scale_up        3187.938612
#                                                    vitamin_a_fortification_scale_up   3187.938612
# birth_weight_mean_in_2020_among_male_iron_forti... baseline                           3158.871781
#                                                    folic_acid_fortification_scale_up  3158.871781
#                                                    iron_fortification_scale_up        3158.871781
#                                                    vitamin_a_fortification_scale_up   3158.871781
# birth_weight_mean_in_2021_among_female_iron_for... baseline                           3254.115407
#                                                    folic_acid_fortification_scale_up  3254.115407
#                                                    iron_fortification_scale_up        3254.115407
#                                                    vitamin_a_fortification_scale_up   3254.115407
# birth_weight_mean_in_2021_among_female_iron_for... baseline                           3196.405055
#                                                    folic_acid_fortification_scale_up  3196.405055
#                                                    iron_fortification_scale_up        3196.405055
#                                                    vitamin_a_fortification_scale_up   3196.405055
# birth_weight_mean_in_2021_among_male_iron_forti... baseline                           3135.059464
#                                                    folic_acid_fortification_scale_up  3135.059464
#                                                    iron_fortification_scale_up        3135.059464
#                                                    vitamin_a_fortification_scale_up   3135.059464
# birth_weight_mean_in_2021_among_male_iron_forti... baseline                           3159.934792
#                                                    folic_acid_fortification_scale_up  3159.934792
# ...                                                                                           ...
# birth_weight_sd_in_2024_among_female_iron_forti... iron_fortification_scale_up         635.856294
#                                                    vitamin_a_fortification_scale_up    635.856294
# birth_weight_sd_in_2024_among_female_iron_forti... baseline                            637.646210
#                                                    folic_acid_fortification_scale_up   637.646210
#                                                    iron_fortification_scale_up         637.646210
#                                                    vitamin_a_fortification_scale_up    637.646210
# birth_weight_sd_in_2024_among_male_iron_fortifi... baseline                            631.404789
#                                                    folic_acid_fortification_scale_up   631.404789
#                                                    iron_fortification_scale_up         631.404789
#                                                    vitamin_a_fortification_scale_up    631.404789
# birth_weight_sd_in_2024_among_male_iron_fortifi... baseline                            630.401699
#                                                    folic_acid_fortification_scale_up   630.401699
#                                                    iron_fortification_scale_up         630.401699
#                                                    vitamin_a_fortification_scale_up    630.401699
# birth_weight_sd_in_2025_among_female_iron_forti... baseline                            634.417804
#                                                    folic_acid_fortification_scale_up   634.417804
#                                                    iron_fortification_scale_up         634.417804
#                                                    vitamin_a_fortification_scale_up    634.417804
# birth_weight_sd_in_2025_among_female_iron_forti... baseline                            640.475882
#                                                    folic_acid_fortification_scale_up   640.475882
#                                                    iron_fortification_scale_up         640.475882
#                                                    vitamin_a_fortification_scale_up    640.475882
# birth_weight_sd_in_2025_among_male_iron_fortifi... baseline                            625.278122
#                                                    folic_acid_fortification_scale_up   625.278122
#                                                    iron_fortification_scale_up         625.278122
#                                                    vitamin_a_fortification_scale_up    625.278122
# birth_weight_sd_in_2025_among_male_iron_fortifi... baseline                            615.325980
#                                                    folic_acid_fortification_scale_up   615.325980
#                                                    iron_fortification_scale_up         615.325980
#                                                    vitamin_a_fortification_scale_up    615.325980
#
#
#                                                                                               max
# measure                                            scenario
# birth_weight_mean_in_2020_among_female_iron_for... baseline                           3244.991958
#                                                    folic_acid_fortification_scale_up  3244.991958
#                                                    iron_fortification_scale_up        3244.991958
#                                                    vitamin_a_fortification_scale_up   3244.991958
# birth_weight_mean_in_2020_among_female_iron_for... baseline                           3221.382215
#                                                    folic_acid_fortification_scale_up  3221.382215
#                                                    iron_fortification_scale_up        3221.382215
#                                                    vitamin_a_fortification_scale_up   3221.382215
# birth_weight_mean_in_2020_among_male_iron_forti... baseline                           3223.445094
#                                                    folic_acid_fortification_scale_up  3223.445094
#                                                    iron_fortification_scale_up        3223.445094
#                                                    vitamin_a_fortification_scale_up   3223.445094
# birth_weight_mean_in_2020_among_male_iron_forti... baseline                           3170.156460
#                                                    folic_acid_fortification_scale_up  3170.156460
#                                                    iron_fortification_scale_up        3170.156460
#                                                    vitamin_a_fortification_scale_up   3170.156460
# birth_weight_mean_in_2021_among_female_iron_for... baseline                           3256.799444
#                                                    folic_acid_fortification_scale_up  3256.799444
#                                                    iron_fortification_scale_up        3256.799444
#                                                    vitamin_a_fortification_scale_up   3256.799444
# birth_weight_mean_in_2021_among_female_iron_for... baseline                           3219.144851
#                                                    folic_acid_fortification_scale_up  3219.144851
#                                                    iron_fortification_scale_up        3219.144851
#                                                    vitamin_a_fortification_scale_up   3219.144851
# birth_weight_mean_in_2021_among_male_iron_forti... baseline                           3135.681691
#                                                    folic_acid_fortification_scale_up  3135.681691
#                                                    iron_fortification_scale_up        3135.681691
#                                                    vitamin_a_fortification_scale_up   3135.681691
# birth_weight_mean_in_2021_among_male_iron_forti... baseline                           3167.262764
#                                                    folic_acid_fortification_scale_up  3167.262764
# ...                                                                                           ...
# birth_weight_sd_in_2024_among_female_iron_forti... iron_fortification_scale_up         638.282530
#                                                    vitamin_a_fortification_scale_up    638.282530
# birth_weight_sd_in_2024_among_female_iron_forti... baseline                            644.046775
#                                                    folic_acid_fortification_scale_up   644.046775
#                                                    iron_fortification_scale_up         644.046775
#                                                    vitamin_a_fortification_scale_up    644.046775
# birth_weight_sd_in_2024_among_male_iron_fortifi... baseline                            645.292850
#                                                    folic_acid_fortification_scale_up   645.292850
#                                                    iron_fortification_scale_up         645.292850
#                                                    vitamin_a_fortification_scale_up    645.292850
# birth_weight_sd_in_2024_among_male_iron_fortifi... baseline                            631.240614
#                                                    folic_acid_fortification_scale_up   631.240614
#                                                    iron_fortification_scale_up         631.240614
#                                                    vitamin_a_fortification_scale_up    631.240614
# birth_weight_sd_in_2025_among_female_iron_forti... baseline                            640.432902
#                                                    folic_acid_fortification_scale_up   640.432902
#                                                    iron_fortification_scale_up         640.432902
#                                                    vitamin_a_fortification_scale_up    640.432902
# birth_weight_sd_in_2025_among_female_iron_forti... baseline                            646.144665
#                                                    folic_acid_fortification_scale_up   646.144665
#                                                    iron_fortification_scale_up         646.144665
#                                                    vitamin_a_fortification_scale_up    646.144665
# birth_weight_sd_in_2025_among_male_iron_fortifi... baseline                            636.255858
#                                                    folic_acid_fortification_scale_up   636.255858
#                                                    iron_fortification_scale_up         636.255858
#                                                    vitamin_a_fortification_scale_up    636.255858
# birth_weight_sd_in_2025_among_male_iron_fortifi... baseline                            616.339898
#                                                    folic_acid_fortification_scale_up   616.339898
#                                                    iron_fortification_scale_up         616.339898
#                                                    vitamin_a_fortification_scale_up    616.339898
#
# [192 rows x 16 columns]

# %%
# mean birth weight should be identical between these three scenarios
    # issue with common random numbers?

# %%
ga = pd.read_hdf(output_dirs[0] + 'gestational_age.hdf')
ga.head()
# Out:
#                 measure  input_draw                           scenario  \
# 0  gestational_age_mean         357                           baseline
# 1  gestational_age_mean         357  folic_acid_fortification_scale_up
# 2  gestational_age_mean         357        iron_fortification_scale_up
# 3  gestational_age_mean         357   vitamin_a_fortification_scale_up
# 4  gestational_age_mean         602                           baseline
#
#        value
# 0  38.705731
# 1  38.705731
# 2  38.705731
# 3  38.705731
# 4  38.318606

# %%
np.unique(ga['measure'])
# Out:
# array(['gestational_age_mean', 'gestational_age_sd'], dtype=object)

# %%
ga_mean = ga.groupby(['measure','scenario']).describe()
ga_mean
# Out:
#                                                        input_draw         \
#                                                             count   mean
# measure              scenario
# gestational_age_mean baseline                                 2.0  479.5
#                      folic_acid_fortification_scale_up        2.0  479.5
#                      iron_fortification_scale_up              2.0  479.5
#                      vitamin_a_fortification_scale_up         2.0  479.5
# gestational_age_sd   baseline                                 2.0  479.5
#                      folic_acid_fortification_scale_up        2.0  479.5
#                      iron_fortification_scale_up              2.0  479.5
#                      vitamin_a_fortification_scale_up         2.0  479.5
#
#                                                                            \
#                                                                std    min
# measure              scenario
# gestational_age_mean baseline                           173.241161  357.0
#                      folic_acid_fortification_scale_up  173.241161  357.0
#                      iron_fortification_scale_up        173.241161  357.0
#                      vitamin_a_fortification_scale_up   173.241161  357.0
# gestational_age_sd   baseline                           173.241161  357.0
#                      folic_acid_fortification_scale_up  173.241161  357.0
#                      iron_fortification_scale_up        173.241161  357.0
#                      vitamin_a_fortification_scale_up   173.241161  357.0
#
#                                                                                \
#                                                            25%    50%     75%
# measure              scenario
# gestational_age_mean baseline                           418.25  479.5  540.75
#                      folic_acid_fortification_scale_up  418.25  479.5  540.75
#                      iron_fortification_scale_up        418.25  479.5  540.75
#                      vitamin_a_fortification_scale_up   418.25  479.5  540.75
# gestational_age_sd   baseline                           418.25  479.5  540.75
#                      folic_acid_fortification_scale_up  418.25  479.5  540.75
#                      iron_fortification_scale_up        418.25  479.5  540.75
#                      vitamin_a_fortification_scale_up   418.25  479.5  540.75
#
#                                                               value  \
#                                                           max count
# measure              scenario
# gestational_age_mean baseline                           602.0   2.0
#                      folic_acid_fortification_scale_up  602.0   2.0
#                      iron_fortification_scale_up        602.0   2.0
#                      vitamin_a_fortification_scale_up   602.0   2.0
# gestational_age_sd   baseline                           602.0   2.0
#                      folic_acid_fortification_scale_up  602.0   2.0
#                      iron_fortification_scale_up        602.0   2.0
#                      vitamin_a_fortification_scale_up   602.0   2.0
#
#                                                                              \
#                                                              mean       std
# measure              scenario
# gestational_age_mean baseline                           38.512168  0.273738
#                      folic_acid_fortification_scale_up  38.512168  0.273738
#                      iron_fortification_scale_up        38.512168  0.273738
#                      vitamin_a_fortification_scale_up   38.512168  0.273738
# gestational_age_sd   baseline                            2.252619  1.421868
#                      folic_acid_fortification_scale_up   2.252619  1.421868
#                      iron_fortification_scale_up         2.252619  1.421868
#                      vitamin_a_fortification_scale_up    2.252619  1.421868
#
#                                                                               \
#                                                               min        25%
# measure              scenario
# gestational_age_mean baseline                           38.318606  38.415387
#                      folic_acid_fortification_scale_up  38.318606  38.415387
#                      iron_fortification_scale_up        38.318606  38.415387
#                      vitamin_a_fortification_scale_up   38.318606  38.415387
# gestational_age_sd   baseline                            1.247207   1.749913
#                      folic_acid_fortification_scale_up   1.247207   1.749913
#                      iron_fortification_scale_up         1.247207   1.749913
#                      vitamin_a_fortification_scale_up    1.247207   1.749913
#
#                                                                               \
#                                                               50%        75%
# measure              scenario
# gestational_age_mean baseline                           38.512168  38.608949
#                      folic_acid_fortification_scale_up  38.512168  38.608949
#                      iron_fortification_scale_up        38.512168  38.608949
#                      vitamin_a_fortification_scale_up   38.512168  38.608949
# gestational_age_sd   baseline                            2.252619   2.755326
#                      folic_acid_fortification_scale_up   2.252619   2.755326
#                      iron_fortification_scale_up         2.252619   2.755326
#                      vitamin_a_fortification_scale_up    2.252619   2.755326
#
#
#                                                               max
# measure              scenario
# gestational_age_mean baseline                           38.705731
#                      folic_acid_fortification_scale_up  38.705731
#                      iron_fortification_scale_up        38.705731
#                      vitamin_a_fortification_scale_up   38.705731
# gestational_age_sd   baseline                            3.258032
#                      folic_acid_fortification_scale_up   3.258032
#                      iron_fortification_scale_up         3.258032
#                      vitamin_a_fortification_scale_up    3.258032

# %%
births = pd.read_hdf(output_dirs[0] + 'births.hdf')
births.head()
# Out:
#    year     sex folic_acid_fortification_group      measure  input_draw  \
# 0  2020  female                        covered  live_births         357
# 1  2020  female                        covered  live_births         357
# 2  2020  female                        covered  live_births         357
# 3  2020  female                        covered  live_births         357
# 4  2020  female                        covered  live_births         357
#
#                             scenario  value
# 0                           baseline   76.0
# 1                           baseline    0.0
# 2                           baseline   11.0
# 3  folic_acid_fortification_scale_up   76.0
# 4  folic_acid_fortification_scale_up    0.0

# %%
np.unique(births['measure'])
# Out:
# array(['live_births'], dtype=object)

# %%
births_mean = births.groupby(['input_draw','scenario']).sum().groupby(['scenario']).mean()
births_mean
# Out:
#                                      value
# scenario
# baseline                           22489.5
# folic_acid_fortification_scale_up  22489.5
# iron_fortification_scale_up        22489.5
# vitamin_a_fortification_scale_up   22489.5

# %% [markdown]
# # Conclusion
#
# It appears that there are different numbers of live births and different mean values for birth weight and gestational age for the baseline, vitamin a, and folic acid scenarios. Because fertility, birth weight, nor gestational age are affected by the vitamin a or f
