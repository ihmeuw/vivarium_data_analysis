# %%
from vivarium import Artifact
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from db_queries import get_ids, get_outputs
import scipy.stats

# !whoami
# !date
# Out:
# alibow
# Wed Jun 24 10:36:30 PDT 2020

# %%
data = pd.read_hdf('/share/costeffectiveness/results/vivarium_conic_lsff/00_bugfix/india_new_start_date/output.hdf')
data.head()
# Out:
#                                total_population_untracked  \
# input_draw_number random_seed
# 946.0             9.0                              9946.0
# 829.0             9.0                              9941.0
# 946.0             15.0                             9957.0
# 829.0             15.0                             9937.0
# 946.0             15.0                             9957.0
#
#                                total_population_tracked  total_population  \
# input_draw_number random_seed
# 946.0             9.0                            9760.0           19706.0
# 829.0             9.0                            9634.0           19575.0
# 946.0             15.0                           9608.0           19565.0
# 829.0             15.0                           9502.0           19439.0
# 946.0             15.0                           9608.0           19565.0
#
#                                diarrheal_diseases_prevalent_cases_at_sim_end  \
# input_draw_number random_seed
# 946.0             9.0                                                  386.0
# 829.0             9.0                                                  285.0
# 946.0             15.0                                                 367.0
# 829.0             15.0                                                 304.0
# 946.0             15.0                                                 386.0
#
#                                susceptible_to_diarrheal_diseases_event_count  \
# input_draw_number random_seed
# 946.0             9.0                                                22999.0
# 829.0             9.0                                                19732.0
# 946.0             15.0                                               22062.0
# 829.0             15.0                                               19182.0
# 946.0             15.0                                               22846.0
#
#                                diarrheal_diseases_event_count  \
# input_draw_number random_seed
# 946.0             9.0                                 23495.0
# 829.0             9.0                                 20110.0
# 946.0             15.0                                22534.0
# 829.0             15.0                                19606.0
# 946.0             15.0                                23337.0
#
#                                measles_prevalent_cases_at_sim_end  \
# input_draw_number random_seed
# 946.0             9.0                                       865.0
# 829.0             9.0                                      2256.0
# 946.0             15.0                                      913.0
# 829.0             15.0                                     2235.0
# 946.0             15.0                                      951.0
#
#                                susceptible_to_measles_event_count  \
# input_draw_number random_seed
# 946.0             9.0                                         0.0
# 829.0             9.0                                         0.0
# 946.0             15.0                                        0.0
# 829.0             15.0                                        0.0
# 946.0             15.0                                        0.0
#
#                                measles_event_count  \
# input_draw_number random_seed
# 946.0             9.0                        879.0
# 829.0             9.0                       2297.0
# 946.0             15.0                       929.0
# 829.0             15.0                      2272.0
# 946.0             15.0                       967.0
#
#                                recovered_from_measles_event_count  ...  \
# input_draw_number random_seed                                      ...
# 946.0             9.0                                       860.0  ...
# 829.0             9.0                                      2256.0  ...
# 946.0             15.0                                      906.0  ...
# 829.0             15.0                                     2224.0  ...
# 946.0             15.0                                      942.0  ...
#
#                                anemia_moderate_person_time_in_2024_among_female_in_age_group_1_to_4  \
# input_draw_number random_seed
# 946.0             9.0                                                1193.716632
# 829.0             9.0                                                1286.899384
# 946.0             15.0                                               1193.305955
# 829.0             15.0                                               1245.297741
# 946.0             15.0                                               1193.305955
#
#                                anemia_severe_person_time_in_2024_among_male_in_age_group_early_neonatal  \
# input_draw_number random_seed
# 946.0             9.0                                                   5.256674
# 829.0             9.0                                                   4.024641
# 946.0             15.0                                                  4.435318
# 829.0             15.0                                                  4.722793
# 946.0             15.0                                                  4.435318
#
#                                anemia_severe_person_time_in_2024_among_female_in_age_group_early_neonatal  \
# input_draw_number random_seed
# 946.0             9.0                                                   4.969199
# 829.0             9.0                                                   4.722793
# 946.0             15.0                                                  4.476386
# 829.0             15.0                                                  4.517454
# 946.0             15.0                                                  4.476386
#
#                                anemia_severe_person_time_in_2024_among_male_in_age_group_late_neonatal  \
# input_draw_number random_seed
# 946.0             9.0                                                   4.188912
# 829.0             9.0                                                   2.669405
# 946.0             15.0                                                  2.505133
# 829.0             15.0                                                  2.710472
# 946.0             15.0                                                  2.505133
#
#                                anemia_severe_person_time_in_2024_among_female_in_age_group_late_neonatal  \
# input_draw_number random_seed
# 946.0             9.0                                                   2.587269
# 829.0             9.0                                                   3.408624
# 946.0             15.0                                                  2.340862
# 829.0             15.0                                                  3.367556
# 946.0             15.0                                                  2.340862
#
#                                anemia_severe_person_time_in_2024_among_male_in_age_group_post_neonatal  \
# input_draw_number random_seed
# 946.0             9.0                                                  41.273101
# 829.0             9.0                                                  32.772074
# 946.0             15.0                                                 30.513347
# 829.0             15.0                                                 37.002053
# 946.0             15.0                                                 30.513347
#
#                                anemia_severe_person_time_in_2024_among_female_in_age_group_post_neonatal  \
# input_draw_number random_seed
# 946.0             9.0                                                  22.874743
# 829.0             9.0                                                  18.562628
# 946.0             15.0                                                 18.932238
# 829.0             15.0                                                 26.201232
# 946.0             15.0                                                 18.932238
#
#                                anemia_severe_person_time_in_2024_among_male_in_age_group_1_to_4  \
# input_draw_number random_seed
# 946.0             9.0                                                  82.012320
# 829.0             9.0                                                  80.082136
# 946.0             15.0                                                 87.638604
# 829.0             15.0                                                 61.971253
# 946.0             15.0                                                 87.638604
#
#                                anemia_severe_person_time_in_2024_among_female_in_age_group_1_to_4  \
# input_draw_number random_seed
# 946.0             9.0                                                  56.221766
# 829.0             9.0                                                  63.285421
# 946.0             15.0                                                 52.772074
# 829.0             15.0                                                 70.800821
# 946.0             15.0                                                 52.772074
#
#                                fortification_intervention.scenario
# input_draw_number random_seed
# 946.0             9.0                                     baseline
# 829.0             9.0                  iron_fortification_scale_up
# 946.0             15.0            vitamin_a_fortification_scale_up
# 829.0             15.0                                    baseline
# 946.0             15.0                 iron_fortification_scale_up
#
# [5 rows x 14445 columns]

# %%
data.shape

# dataframe has 560 rows
# Out:
# (30, 14445)

# %%
# number of input_draws

len(np.unique(data['input_draw']))
# Out:
# 5

# %%
# number of random seeds

len(np.unique(data['random_seed']))
# Out:
# 2

# %%
# number of scenarios

len(np.unique(data['fortification_intervention.scenario']))
# Out:
# 3

# %%
# COMPLETE! :)
