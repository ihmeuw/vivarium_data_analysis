# %%
from vivarium import Artifact
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from db_queries import get_ids, get_outputs
import scipy.stats

# !whoami
# !date
# Out:
# alibow
# Mon Jun 22 11:39:26 PDT 2020

# %%
data = pd.read_hdf('/share/costeffectiveness/results/vivarium_conic_lsff/00_bugfix/25draw_5seed/india/2020_06_19_18_11_00/output.hdf')
data.head()
# Out:
#                                total_population_untracked  \
# input_draw_number random_seed
# 21.0              8.0                              9947.0
# 29.0              26.0                             9959.0
# 394.0             5.0                              9944.0
# 829.0             40.0                             9947.0
# 417.0             5.0                              9953.0
#
#                                total_population_tracked  total_population  \
# input_draw_number random_seed
# 21.0              8.0                            9283.0           19230.0
# 29.0              26.0                           9410.0           19369.0
# 394.0             5.0                            9480.0           19424.0
# 829.0             40.0                           9613.0           19560.0
# 417.0             5.0                            9566.0           19519.0
#
#                                diarrheal_diseases_prevalent_cases_at_sim_end  \
# ...

# %%
data.shape

# dataframe has 560 rows
# Out:
# (560, 15673)

# %%
# number of input_draws

len(np.unique(data['input_draw']))
# Out:
# 25

# %%
# number of random seeds

len(np.unique(data['random_seed']))
# Out:
# 5

# %%
# number of scenarios

len(np.unique(data['fortification_intervention.scenario']))
# Out:
# 5

# %%
# there should be 625 rows, but there are only 560

25 * 5 * 5
# Out:
# 625
