# %%
import pandas as pd, numpy as np
import vivarium_output_loader as vol
# import lsff_output_processing as lop
import lsff_summarizer
from lsff_summarizer import LSFFOutputSummarizer

# !whoami
# !date
# Out:
# ndbs
# Fri Jun  5 17:17:11 PDT 2020

# %%
# %load_ext autoreload
# %autoreload 2

# %%
base_directory = '/share/costeffectiveness/results/vivarium_conic_lsff/00_bugfix'
india_maternal_directory = base_directory + '/maternal_birthweight_stratified'
india_v6_directory = base_directory + '/v6.0_prelim_maternal_iron_lri_bp/india_5_20'

locations_paths_m = {'India': india_maternal_directory}
locations_paths_6 = {'India': india_v6_directory}

# %%
raw_output_6 = vol.load_output_by_location(locations_paths_6)
raw_output_6.head()
# Out:
#                                total_population_untracked  \
# input_draw_number random_seed
# 232.0             154.0                            9957.0
# 357.0             161.0                            9949.0
# 29.0              161.0                            9953.0
# 357.0             161.0                            9949.0
# 680.0             67.0                             9963.0
#
#                                total_population_tracked  total_population  \
# input_draw_number random_seed
# 232.0             154.0                          9505.0           19462.0
# 357.0             161.0                          9539.0           19488.0
# 29.0              161.0                          9677.0           19630.0
# 357.0             161.0                          9539.0           19488.0
# 680.0             67.0                           9596.0           19559.0
#
#                                diarrheal_diseases_prevalent_cases_at_sim_end  \
# ...

# %%
output6 = LSFFOutputSummarizer(raw_output_6)
output6.print_column_report()
# Out:
# Number of data columns in output: 15418
# Total number of columns captured in categories: 15418
#
# Number of columns in each category:
#  {'input_draw': 1, 'random_seed': 1, 'location': 1, 'intervention': 1, 'run_time': 0, 'diseases_at_end': 4, 'transition_count': 3465, 'population': 5, 'person_time': 432, 'state_person_time': 4320, 'treated_days': 0, 'mortality': 2160, 'total_daly': 2, 'yld': 2592, 'yll': 2160, 'categorical_risk': 0, 'birth_prevalence': 108, 'live_births': 108, 'proportion': 2, 'distribution_mean': 28, 'distribution_variance': 0, 'distribution_std_dev': 28, 'prevalence': 0}
#
# Missing (0 data column(s) not captured in a category):
#  set()
#
# Repeated (0 data column(s) appearing in more than one category):
#  {}
#
# Empty categories (5 categories with no matching data columns):
#  ['run_time', 'treated_days', 'categorical_risk', 'distribution_variance', 'prevalence']

# %%
raw_output_6.filter(regex=r'measles\w+event_count').head()
# Out:
#                                susceptible_to_measles_event_count  \
# input_draw_number random_seed
# 232.0             154.0                                       0.0
# 357.0             161.0                                       0.0
# 29.0              161.0                                       0.0
# 357.0             161.0                                       0.0
# 680.0             67.0                                        0.0
#
#                                measles_event_count  \
# input_draw_number random_seed
# 232.0             154.0                     1069.0
# 357.0             161.0                      352.0
# 29.0              161.0                     1112.0
# 357.0             161.0                      429.0
# 680.0             67.0                       693.0
#
#                                recovered_from_measles_event_count  \
# input_draw_number random_seed
# 232.0             154.0                                    1053.0
# ...

# %%
raw_output_6.filter(regex=r'vitamin_a\w+event_count|scenario').head()
# Out:
#                                susceptible_to_vitamin_a_deficiency_to_vitamin_a_deficiency_event_count_in_2020_among_male_in_age_group_early_neonatal_folic_acid_unknown_vitamin_a_uncovered  \
# input_draw_number random_seed
# 232.0             154.0                                                      0.0
# 357.0             161.0                                                     13.0
# 29.0              161.0                                                     10.0
# 357.0             161.0                                                     13.0
# 680.0             67.0                                                       6.0
#
#                                susceptible_to_vitamin_a_deficiency_to_vitamin_a_deficiency_event_count_in_2020_among_female_in_age_group_early_neonatal_folic_acid_unknown_vitamin_a_uncovered  \
# input_draw_number random_seed
# 232.0             154.0                                                      4.0
# ...
