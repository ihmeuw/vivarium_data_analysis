# %%
import pandas as pd, numpy as np
import lsff_output_processing as lop
import lsff_summarizer
from lsff_summarizer import LSFFOutputSummarizer

# !whoami
# !date
# Out:
# ndbs
# Fri Mar 27 13:21:45 PDT 2020

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load the raw `output.hdf` file

# %%
base_directory = '/share/costeffectiveness/results/vivarium_conic_lsff/v4.0_folic_acid_fortification'

locations_rundates = {
    'Ethiopia': '2020_03_18_23_04_26',
    'India': '2020_03_18_23_04_36',
    'Nigeria': '2020_03_18_23_04_42',
}

# %%
raw_output = lop.load_by_location_and_rundate(base_directory, locations_rundates)
raw_output.head()
# Out:
#                                total_population_untracked  \
# input_draw_number random_seed
# 602.0             199.0                            9863.0
# 514.0             114.0                            9894.0
# 29.0              199.0                            9894.0
# 357.0             114.0                            9890.0
# 514.0             207.0                            9896.0
#
#                                total_population_tracked  total_population  \
# input_draw_number random_seed
# 602.0             199.0                         11393.0           21256.0
# 514.0             114.0                         11356.0           21250.0
# 29.0              199.0                         11245.0           21139.0
# 357.0             114.0                         11323.0           21213.0
# 514.0             207.0                         11279.0           21175.0
#
#                                diarrheal_diseases_prevalent_cases_at_sim_end  \
# ...

# %% [markdown]
# ## Create an OutputSummarizer and check column categories

# %%
output = LSFFOutputSummarizer(raw_output)
output.print_column_report()
# Out:
# Number of data columns in output: 4290
# Total number of columns captured in categories: 4290
#
# Number of columns in each category:
#  {'input_draw': 1, 'random_seed': 1, 'location': 1, 'intervention': 1, 'run_time': 0, 'diseases_at_end': 4, 'transition_count': 879, 'population': 5, 'person_time': 1014, 'treated_days': 0, 'mortality': 720, 'total_daly': 2, 'yld': 864, 'yll': 720, 'categorical_risk': 0, 'graded_sequela': 0, 'birth_prevalence': 36, 'live_births': 36, 'proportion': 2, 'distribution_mean': 2, 'distribution_std_dev': 2, 'prevalence': 0}
#
# Missing (0 data column(s) not captured in a category):
#  set()
#
# Repeated (0 data column(s) appearing in more than one category):
#  {}
#
# Empty categories (5 categories with no matching data columns):
#  ['run_time', 'treated_days', 'categorical_risk', 'graded_sequela', 'prevalence']

# %% [markdown]
# ## Test the new `subdata()` function

# %%
output.subdata().head()
# Out:
#                                total_population_untracked  \
# input_draw_number random_seed
# 602.0             199.0                            9863.0
# 514.0             114.0                            9894.0
# 29.0              199.0                            9894.0
# 357.0             114.0                            9890.0
# 514.0             207.0                            9896.0
#
#                                total_population_tracked  total_population  \
# input_draw_number random_seed
# 602.0             199.0                         11393.0           21256.0
# 514.0             114.0                         11356.0           21250.0
# 29.0              199.0                         11245.0           21139.0
# 357.0             114.0                         11323.0           21213.0
# 514.0             207.0                         11279.0           21175.0
#
#                                diarrheal_diseases_prevalent_cases_at_sim_end  \
# ...

# %% [markdown]
# ## See what some of the data looks like

# %%
output.subdata('intervention').tail(10)
# Out:
#                               fortification_intervention.scenario
# input_draw_number random_seed
# 482.0             66.0          folic_acid_fortification_scale_up
# 21.0              235.0         folic_acid_fortification_scale_up
# 674.0             35.0                                   baseline
# 602.0             185.0         folic_acid_fortification_scale_up
# 21.0              6.0                                    baseline
# 55.0              88.0          folic_acid_fortification_scale_up
#                   129.0                                  baseline
# 394.0             337.0                                  baseline
# 482.0             35.0                                   baseline
# 620.0             377.0                                  baseline

# %% [markdown]
# ## Hmm, it looks like some YLDs are missing in 2020
#
# See below for checking which is 0

# %%
output.subdata('yld').head()
# Out:
#                                ylds_due_to_diarrheal_diseases_in_2020_among_male_in_age_group_1_to_4_folic_acid_fortification_group_true  \
# input_draw_number random_seed
# 602.0             199.0                                                      0.0
# 514.0             114.0                                                      0.0
# 29.0              199.0                                                      0.0
# 357.0             114.0                                                      0.0
# 514.0             207.0                                                      0.0
#
#                                ylds_due_to_diarrheal_diseases_in_2020_among_female_in_age_group_1_to_4_folic_acid_fortification_group_true  \
# input_draw_number random_seed
# 602.0             199.0                                                      0.0
# 514.0             114.0                                                      0.0
# ...

# %% [markdown]
# ## See if there are any columns with 'anemia' in the name
#
# Nope.

# %%
raw_output.filter(regex='anemia').head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(602.0, 199.0), (514.0, 114.0), (29.0, 199.0), (357.0, 114.0), (514.0, 207.0)]

# %% [markdown]
# ## Look at the live births columns

# %%
output.subdata('live_births').head()
# Out:
#                                live_births_in_2020_among_male_folic_acid_fortification_group_unknown  \
# input_draw_number random_seed
# 602.0             199.0                                                      0.0
# 514.0             114.0                                                      0.0
# 29.0              199.0                                                      0.0
# 357.0             114.0                                                      0.0
# 514.0             207.0                                                      0.0
#
#                                live_births_in_2020_among_female_folic_acid_fortification_group_unknown  \
# input_draw_number random_seed
# 602.0             199.0                                                      0.0
# 514.0             114.0                                                      0.0
# 29.0              199.0                                                      0.0
# ...

# %%
output.columns('live_births')
# Out:
# ['live_births_in_2020_among_male_folic_acid_fortification_group_unknown',
#  'live_births_in_2020_among_female_folic_acid_fortification_group_unknown',
#  'live_births_in_2021_among_male_folic_acid_fortification_group_unknown',
#  'live_births_in_2021_among_female_folic_acid_fortification_group_unknown',
#  'live_births_in_2022_among_male_folic_acid_fortification_group_unknown',
#  'live_births_in_2022_among_female_folic_acid_fortification_group_unknown',
#  'live_births_in_2023_among_male_folic_acid_fortification_group_unknown',
#  'live_births_in_2023_among_female_folic_acid_fortification_group_unknown',
#  'live_births_in_2024_among_male_folic_acid_fortification_group_unknown',
#  'live_births_in_2024_among_female_folic_acid_fortification_group_unknown',
#  'live_births_in_2025_among_male_folic_acid_fortification_group_unknown',
#  'live_births_in_2025_among_female_folic_acid_fortification_group_unknown',
#  'live_births_in_2020_among_male_folic_acid_fortification_group_true',
# ...

# %% [markdown]
# ## Look at the birth prevalence columns

# %%
output.columns('birth_prevalence')
# Out:
# ['born_with_ntds_in_2020_among_male_folic_acid_fortification_group_unknown',
#  'born_with_ntds_in_2020_among_female_folic_acid_fortification_group_unknown',
#  'born_with_ntds_in_2021_among_male_folic_acid_fortification_group_unknown',
#  'born_with_ntds_in_2021_among_female_folic_acid_fortification_group_unknown',
#  'born_with_ntds_in_2022_among_male_folic_acid_fortification_group_unknown',
#  'born_with_ntds_in_2022_among_female_folic_acid_fortification_group_unknown',
#  'born_with_ntds_in_2023_among_male_folic_acid_fortification_group_unknown',
#  'born_with_ntds_in_2023_among_female_folic_acid_fortification_group_unknown',
#  'born_with_ntds_in_2024_among_male_folic_acid_fortification_group_unknown',
#  'born_with_ntds_in_2024_among_female_folic_acid_fortification_group_unknown',
#  'born_with_ntds_in_2025_among_male_folic_acid_fortification_group_unknown',
#  'born_with_ntds_in_2025_among_female_folic_acid_fortification_group_unknown',
# ...

# %% [markdown]
# ## Look at the distribution mean and standard deviation columns

# %%
output.subdata('distribution_mean').head()
# Out:
#                                birth_weight_mean  gestational_age_mean
# input_draw_number random_seed
# 602.0             199.0              3058.394658             37.743470
# 514.0             114.0              3360.379760             38.689182
# 29.0              199.0              3318.070101             39.338675
# 357.0             114.0              3271.311054             39.731728
# 514.0             207.0              3480.696569             38.877923

# %%
output.subdata('distribution_std_dev').head()
# Out:
#                                birth_weight_sd  gestational_age_sd
# input_draw_number random_seed
# 602.0             199.0             387.470511            2.188064
# 514.0             114.0             392.128748            0.633492
# 29.0              199.0             504.097894            1.066452
# 357.0             114.0             876.948043            1.228437
# 514.0             207.0             483.239313            0.871262

# %% [markdown]
# ## Look for columns relating to neural tube defects
#
# Looks like we just have birth prevalence and overall prevalence at end of sim, but not prevalence in different age groups.

# %%
raw_output.filter(regex='neural|ntd').head()
# Out:
#                                neural_tube_defects_prevalent_cases_at_sim_end  \
# input_draw_number random_seed
# 602.0             199.0                                                  13.0
# 514.0             114.0                                                  18.0
# 29.0              199.0                                                   9.0
# 357.0             114.0                                                  16.0
# 514.0             207.0                                                  12.0
#
#                                susceptible_to_neural_tube_defects_event_count  \
# input_draw_number random_seed
# 602.0             199.0                                                   0.0
# 514.0             114.0                                                   0.0
# 29.0              199.0                                                   0.0
# 357.0             114.0                                                   0.0
# ...

# %% [markdown]
# ## Look for columns relating to vitamin A
#
# Looks like we can't compute prevalence of vitamin A deficiency.

# %%
raw_output.filter(regex='vitamin').head()
# Out:
#                                susceptible_to_vitamin_a_deficiency_to_vitamin_a_deficiency_event_count_folic_acid_fortification_group_unknown  \
# input_draw_number random_seed
# 602.0             199.0                                                2109292.0
# 514.0             114.0                                                2173676.0
# 29.0              199.0                                                2030192.0
# 357.0             114.0                                                1946671.0
# 514.0             207.0                                                2139853.0
#
#                                vitamin_a_deficiency_to_susceptible_to_vitamin_a_deficiency_event_count_folic_acid_fortification_group_unknown  \
# input_draw_number random_seed
# 602.0             199.0                                                2109962.0
# 514.0             114.0                                                2174171.0
# ...

# %%
# Look for exposure categories of vitamin A deficiency
raw_output.filter(regex=r'_cat').head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(602.0, 199.0), (514.0, 114.0), (29.0, 199.0), (357.0, 114.0), (514.0, 207.0)]

# %% [markdown]
# ## Check whether diarrhea YLDs are missing
#
# Yes. There were other YLDs missing in 2020 as well -- see 'yld' subdata above.

# %%
raw_output.filter(regex=r'ylds\w+diarrheal_diseases_in_2020\w+1_to_4\w+false').sum()
# Out:
# ylds_due_to_diarrheal_diseases_in_2020_among_male_in_age_group_1_to_4_folic_acid_fortification_group_false      0.0
# ylds_due_to_diarrheal_diseases_in_2020_among_female_in_age_group_1_to_4_folic_acid_fortification_group_false    0.0
# dtype: float64
