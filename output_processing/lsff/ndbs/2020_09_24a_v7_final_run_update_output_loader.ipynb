# %% [markdown]
# # Update functions in `vivarium_output_loader` for loading raw output and count space data
#
# I separated loading data and merging data from different locations into two steps, to make it easier to work with the data in either format:
# *  separate collections of count space dataframes for each country, or
# *  a single collection of dataframes for all countries, with a `'location'` column added to each dataframe.
#
# ## Original Goal: Reproduce bugs Ali found in July and encapsulate them in `.py` files
#
# I did not get very far with this original goal. I was trying to calculate mean differences in birthweigh between covered and uncovered groups so I could draw a histogram to compare to the effect size distribution, and I ran into a weird pandas error in my `.averted` function that I'm still trying to figure out... Basically the dataframe of indices is sometimes missing the broadcast column in the index, and I don't know why. I moved the problem code from here and put it in a new notebook to keep things cleaner.

# %%
import pandas as pd, numpy as np
import vivarium_output_loader as vol
import lsff_output_processing as lop

# !whoami
# !date
# Out:
# ndbs
# Wed Sep 30 16:58:00 PDT 2020

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## 1. Define output directories and load count space data
#
# Make `vivarium_output_loader` more modular by redefining `load_count_data_by_location` and `load_output_by_location`, and adding new `merge` functions to recreate the functionality of the old versions.
#
# Woo hoo! I finally figured out how to merge the countspace dataframes using `pd.concat()` with a list comprehension and a dictionary comprehension.

# %%
base_directory = '/share/costeffectiveness/results/vivarium_conic_lsff'
locations_rundates = {
    'India': '2020_06_26_20_35_00',
    'Nigeria': '2020_06_26_20_28_27',
    'Ethiopia': '2020_06_28_12_40_56',
}
locations_paths = vol.locaction_paths_from_rundates(base_directory, locations_rundates)

data = vol.load_count_data_by_location(locations_paths)
data.keys()
# Out:
# dict_keys(['India', 'Nigeria', 'Ethiopia'])

# %%
# View the table names for one of the countries (they should be the same for all)
data['India'].keys()
# Out:
# dict_keys(['gestational_age', 'transition_count', 'hemoglobin_level', 'deaths', 'state_person_time', 'anemia_state_person_time', 'births_with_ntd', 'population', 'person_time', 'ylls', 'ylds', 'births', 'birth_weight'])

# %%
# Check the Ethiopia state_person_time table to see if years are included,
# since Ali said they were missing on 7/7/2020.
# Yes, they are - it looks like the count_data folder was updated 0n 7/8/2020,
# so maybe Kjell reran the count_space transformation to fix this.
data['Ethiopia']['state_person_time'].head()
# Out:
#    year age_group               cause folic_acid_fortification_group  \
# 0  2020    1_to_4  diarrheal_diseases                        covered
# 1  2020    1_to_4  diarrheal_diseases                        covered
# 2  2020    1_to_4  diarrheal_diseases                        covered
# 3  2020    1_to_4  diarrheal_diseases                        covered
# 4  2020    1_to_4  diarrheal_diseases                        covered
#
#   vitamin_a_fortification_group      measure  input_draw  \
# 0                       covered  person_time          21
# 1                       covered  person_time          21
# 2                       covered  person_time          21
# 3                       covered  person_time          21
# 4                       covered  person_time          29
#
#                                  scenario  value
# 0                                baseline    0.0
# 1       folic_acid_fortification_scale_up    0.0
# 2  iron_folic_acid_fortification_scale_up    0.0
# 3        vitamin_a_fortification_scale_up    0.0
# 4                                baseline    0.0

# %%
data['Ethiopia']['state_person_time'].year.unique()
# Out:
# array(['2020', '2021', '2022', '2023'], dtype=object)

# %%
# Merge the data for all locations
all_data = vol.merge_location_count_data(data)
all_data.keys()
# Out:
# dict_keys(['gestational_age', 'transition_count', 'hemoglobin_level', 'deaths', 'state_person_time', 'anemia_state_person_time', 'births_with_ntd', 'population', 'person_time', 'ylls', 'ylds', 'births', 'birth_weight'])

# %%
# The following should look like the table above, but with a 'location' column added
all_data['state_person_time'].query('location=="Ethiopia"').head()
# Out:
#    location  year age_group               cause  \
# 0  Ethiopia  2020    1_to_4  diarrheal_diseases
# 1  Ethiopia  2020    1_to_4  diarrheal_diseases
# 2  Ethiopia  2020    1_to_4  diarrheal_diseases
# 3  Ethiopia  2020    1_to_4  diarrheal_diseases
# 4  Ethiopia  2020    1_to_4  diarrheal_diseases
#
#   folic_acid_fortification_group vitamin_a_fortification_group      measure  \
# 0                        covered                       covered  person_time
# 1                        covered                       covered  person_time
# 2                        covered                       covered  person_time
# 3                        covered                       covered  person_time
# 4                        covered                       covered  person_time
#
#    input_draw                                scenario  value
# 0          21                                baseline    0.0
# 1          21       folic_acid_fortification_scale_up    0.0
# 2          21  iron_folic_acid_fortification_scale_up    0.0
# 3          21        vitamin_a_fortification_scale_up    0.0
# 4          29                                baseline    0.0

# %%
# Test my new functions for loading and merging the raw output tables
all_output = vol.load_and_merge_location_outputs(locations_paths)
all_output.head()
# Out:
#                                total_population_untracked  \
# input_draw_number random_seed
# 674.0             55.0                             8125.0
#                   35.0                             8078.0
# 55.0              66.0                             8114.0
#                   145.0                            8097.0
# 524.0             389.0                            8108.0
#
#                                total_population_tracked  total_population  \
# input_draw_number random_seed
# 674.0             55.0                           9492.0           17617.0
#                   35.0                           9433.0           17511.0
# 55.0              66.0                           9366.0           17480.0
#                   145.0                          9422.0           17519.0
# 524.0             389.0                          9364.0           17472.0
#
#                                diarrheal_diseases_prevalent_cases_at_sim_end  \
# input_draw_number random_seed
# 674.0             55.0                                                 120.0
#                   35.0                                                 119.0
# 55.0              66.0                                                 122.0
#                   145.0                                                133.0
# 524.0             389.0                                                 86.0
#
#                                susceptible_to_diarrheal_diseases_event_count  \
# input_draw_number random_seed
# 674.0             55.0                                               20880.0
#                   35.0                                               18736.0
# 55.0              66.0                                               18627.0
#                   145.0                                              18952.0
# 524.0             389.0                                              16231.0
#
#                                diarrheal_diseases_event_count  \
# input_draw_number random_seed
# 674.0             55.0                                20997.0
#                   35.0                                18848.0
# 55.0              66.0                                18740.0
#                   145.0                               19075.0
# 524.0             389.0                               16326.0
#
#                                measles_prevalent_cases_at_sim_end  \
# input_draw_number random_seed
# 674.0             55.0                                     2158.0
#                   35.0                                     1845.0
# 55.0              66.0                                     1901.0
#                   145.0                                    1959.0
# 524.0             389.0                                     555.0
#
#                                susceptible_to_measles_event_count  \
# input_draw_number random_seed
# 674.0             55.0                                        0.0
#                   35.0                                        0.0
# 55.0              66.0                                        0.0
#                   145.0                                       0.0
# 524.0             389.0                                       0.0
#
#                                measles_event_count  \
# input_draw_number random_seed
# 674.0             55.0                      2166.0
#                   35.0                      1847.0
# 55.0              66.0                      1906.0
#                   145.0                     1978.0
# 524.0             389.0                      559.0
#
#                                recovered_from_measles_event_count  ...  \
# input_draw_number random_seed                                      ...
# 674.0             55.0                                     2145.0  ...
#                   35.0                                     1840.0  ...
# 55.0              66.0                                     1905.0  ...
#                   145.0                                    1958.0  ...
# 524.0             389.0                                     551.0  ...
#
#                                anemia_severe_person_time_in_2023_among_male_in_age_group_early_neonatal  \
# input_draw_number random_seed
# 674.0             55.0                                                  4.605065
#                   35.0                                                  4.388775
# 55.0              66.0                                                  4.799452
#                   145.0                                                 4.750171
# 524.0             389.0                                                 4.098563
#
#                                anemia_severe_person_time_in_2023_among_female_in_age_group_early_neonatal  \
# input_draw_number random_seed
# 674.0             55.0                                                  3.753593
#                   35.0                                                  4.057495
# 55.0              66.0                                                  3.786448
#                   145.0                                                 3.011636
# 524.0             389.0                                                 4.106776
#
#                                anemia_severe_person_time_in_2023_among_male_in_age_group_late_neonatal  \
# input_draw_number random_seed
# 674.0             55.0                                                  1.856263
#                   35.0                                                  1.848049
# 55.0              66.0                                                  2.751540
#                   145.0                                                 2.934976
# 524.0             389.0                                                 2.729637
#
#                                anemia_severe_person_time_in_2023_among_female_in_age_group_late_neonatal  \
# input_draw_number random_seed
# 674.0             55.0                                                  1.738535
#                   35.0                                                  1.741273
# 55.0              66.0                                                  2.034223
#                   145.0                                                 1.924709
# 524.0             389.0                                                 2.447639
#
#                                anemia_severe_person_time_in_2023_among_male_in_age_group_post_neonatal  \
# input_draw_number random_seed
# 674.0             55.0                                                 24.446270
#                   35.0                                                 26.685832
# 55.0              66.0                                                 25.650924
#                   145.0                                                20.788501
# 524.0             389.0                                                24.574949
#
#                                anemia_severe_person_time_in_2023_among_female_in_age_group_post_neonatal  \
# input_draw_number random_seed
# 674.0             55.0                                                 18.524298
#                   35.0                                                 17.223819
# 55.0              66.0                                                 10.888433
#                   145.0                                                16.424367
# 524.0             389.0                                                22.387406
#
#                                anemia_severe_person_time_in_2023_among_male_in_age_group_1_to_4  \
# input_draw_number random_seed
# 674.0             55.0                                                 41.823409
#                   35.0                                                 54.666667
# 55.0              66.0                                                 43.112936
#                   145.0                                                60.153320
# 524.0             389.0                                                51.222450
#
#                                anemia_severe_person_time_in_2023_among_female_in_age_group_1_to_4  \
# input_draw_number random_seed
# 674.0             55.0                                                 35.583847
#                   35.0                                                 45.757700
# 55.0              66.0                                                 42.633812
#                   145.0                                                38.280630
# 524.0             389.0                                                46.751540
#
#                                   fortification_intervention.scenario  \
# input_draw_number random_seed
# 674.0             55.0         iron_folic_acid_fortification_scale_up
#                   35.0               vitamin_a_fortification_scale_up
# 55.0              66.0         iron_folic_acid_fortification_scale_up
#                   145.0             folic_acid_fortification_scale_up
# 524.0             389.0             folic_acid_fortification_scale_up
#
#                                location
# input_draw_number random_seed
# 674.0             55.0            India
#                   35.0            India
# 55.0              66.0            India
#                   145.0           India
# 524.0             389.0           India
#
# [5 rows x 5442 columns]

# %% [markdown]
# ## 2. Check iron effect on birthweight

# %%
all_data['births'].head()
# Out:
#   location  year     sex folic_acid_fortification_group      measure  \
# 0    India  2020  female                        covered  live_births
# 1    India  2020  female                        covered  live_births
# 2    India  2020  female                        covered  live_births
# 3    India  2020  female                        covered  live_births
# 4    India  2020  female                        covered  live_births
#
#    input_draw                           scenario   value
# 0          21                           baseline  1857.0
# 1          21                           baseline    12.0
# 2          21                           baseline   530.0
# 3          21  folic_acid_fortification_scale_up  1857.0
# 4          21  folic_acid_fortification_scale_up    12.0

# %%
all_data['births'].folic_acid_fortification_group.unique()
# Out:
# array(['covered', 'uncovered', 'unknown'], dtype=object)

# %%
all_data['birth_weight'].head()
# Out:
#   location  year     sex            measure  input_draw  \
# 0    India  2020  female  birth_weight_mean          21
# 1    India  2020  female  birth_weight_mean          21
# 2    India  2020  female  birth_weight_mean          21
# 3    India  2020  female  birth_weight_mean          21
# 4    India  2020  female  birth_weight_mean          21
#
#                                  scenario        value  \
# 0                                baseline  2912.186341
# 1                                baseline  2897.547480
# 2       folic_acid_fortification_scale_up  2912.186341
# 3       folic_acid_fortification_scale_up  2897.547480
# 4  iron_folic_acid_fortification_scale_up  2912.186341
#
#   iron_fortification_group
# 0                uncovered
# 1                  covered
# 2                uncovered
# 3                  covered
# 4                uncovered

# %%
all_data['birth_weight'].iron_fortification_group.unique()
# Out:
# array(['uncovered', 'covered'], dtype=object)

# %%
all_data['birth_weight'].scenario.unique()
# Out:
# array(['baseline', 'folic_acid_fortification_scale_up',
#        'iron_folic_acid_fortification_scale_up',
#        'vitamin_a_fortification_scale_up'], dtype=object)

# %%
all_data['birth_weight'].measure.unique()
# Out:
# array(['birth_weight_mean', 'birth_weight_sd'], dtype=object)

# %%
year = '2022'
scenario = 'iron_folic_acid_fortification_scale_up'
location = 'Nigeria'
draw = 21
query = ('measure=="birth_weight_mean" and scenario==@scenario and year==@year'
         ' and input_draw==@draw and location==@location'
        )
all_data['birth_weight'].query(query)
# Out:
#      location  year     sex            measure  input_draw  \
# 1604  Nigeria  2022  female  birth_weight_mean          21
# 1605  Nigeria  2022  female  birth_weight_mean          21
# 2004  Nigeria  2022    male  birth_weight_mean          21
# 2005  Nigeria  2022    male  birth_weight_mean          21
#
#                                     scenario        value  \
# 1604  iron_folic_acid_fortification_scale_up  3193.635062
# 1605  iron_folic_acid_fortification_scale_up  3201.502874
# 2004  iron_folic_acid_fortification_scale_up  3235.496806
# 2005  iron_folic_acid_fortification_scale_up  3241.154803
#
#      iron_fortification_group
# 1604                uncovered
# 1605                  covered
# 2004                uncovered
# 2005                  covered
