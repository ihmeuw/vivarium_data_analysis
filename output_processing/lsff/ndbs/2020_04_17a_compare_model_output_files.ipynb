# %%
import pandas as pd, numpy as np
import vivarium_output_loader as vol
import lsff_output_processing as lop
import lsff_summarizer
from lsff_summarizer import LSFFOutputSummarizer

# !whoami
# !date
# Out:
# ndbs
# Fri Apr 17 13:41:44 PDT 2020

# %% [markdown]
# ## Create dictionaries to get the correct filepaths
#
# Future goal: Create a dataframe to keep track of correct filepaths

# %%
base_directory3 = '/share/costeffectiveness/results/vivarium_conic_lsff/v3.0_paf_of_one'


locations_rundates3 = {
    'Ethiopia': '2020_03_17_14_59_54',
    'India': '2020_03_17_15_00_02',
    'Nigeria': '2020_03_17_15_00_10',
}

# %%
base_directory4 = '/share/costeffectiveness/results/vivarium_conic_lsff/v4.0_folic_acid_fortification'


locations_rundates4 = {
    'Ethiopia': '2020_03_18_23_04_26',
    'India': '2020_03_18_23_04_36',
    'Nigeria': '2020_03_18_23_04_42',
}

# %%
base_directory5 = '/share/costeffectiveness/results/vivarium_conic_lsff/v5.0_vitamin_a_fortification'

locations_rundates5 = {
    'Ethiopia': '2020_03_26_08_33_10',
    'India': '2020_03_26_21_28_29',
    'Nigeria': '2020_03_24_23_27_55',
}

# %%
raw_output3 = vol.load_by_location_and_rundate(base_directory3, locations_rundates3)
raw_output3.head()
# Out:
#                                total_population_untracked  \
# input_draw_number random_seed
# 21.0              199.0                            9871.0
# 946.0             389.0                            9884.0
# 514.0             129.0                            9906.0
# 482.0             45.0                             9885.0
# 533.0             306.0                            9882.0
#
#                                total_population_tracked  total_population  \
# input_draw_number random_seed
# 21.0              199.0                         11444.0           21315.0
# 946.0             389.0                         11238.0           21122.0
# 514.0             129.0                         11396.0           21302.0
# 482.0             45.0                          11431.0           21316.0
# 533.0             306.0                         11149.0           21031.0
#
#                                diarrheal_diseases_prevalent_cases_at_sim_end  \
# ...

# %%
raw_output5 = vol.load_by_location_and_rundate(base_directory5, locations_rundates5)
raw_output5.head()
# Out:
#                                total_population_untracked  \
# input_draw_number random_seed
# 829.0             245.0                            9877.0
# 155.0             92.0                             9875.0
# 394.0             129.0                            9895.0
# 533.0             134.0                            9861.0
# 155.0             377.0                            9904.0
#
#                                total_population_tracked  total_population  \
# input_draw_number random_seed
# 829.0             245.0                         11344.0           21221.0
# 155.0             92.0                          11196.0           21071.0
# 394.0             129.0                         11165.0           21060.0
# 533.0             134.0                         11270.0           21131.0
# 155.0             377.0                         11341.0           21245.0
#
#                                diarrheal_diseases_prevalent_cases_at_sim_end  \
# ...

# %%
output3 = LSFFOutputSummarizer(raw_output3)
output3.print_column_report()
# Out:
# Number of data columns in output: 10069
# Total number of columns captured in categories: 17581
#
# Number of columns in each category:
#  {'input_draw': 1, 'random_seed': 1, 'location': 1, 'intervention': 0, 'run_time': 0, 'diseases_at_end': 4, 'transition_count': 2329, 'population': 5, 'person_time': 2704, 'treated_days': 0, 'mortality': 1920, 'total_daly': 2, 'yld': 1152, 'yll': 1920, 'categorical_risk': 0, 'graded_sequela': 7512, 'birth_prevalence': 12, 'live_births': 12, 'proportion': 2, 'distribution_mean': 2, 'distribution_std_dev': 2, 'prevalence': 0}
#
# Missing (0 data column(s) not captured in a category):
#  set()
#
# Repeated (7512 data column(s) appearing in more than one category):
# ...

# %%
output5 = LSFFOutputSummarizer(raw_output5)
output5.print_column_report()
# Out:
# Number of data columns in output: 12810
# Total number of columns captured in categories: 12810
#
# Number of columns in each category:
#  {'input_draw': 1, 'random_seed': 1, 'location': 1, 'intervention': 1, 'run_time': 0, 'diseases_at_end': 4, 'transition_count': 2619, 'population': 5, 'person_time': 3042, 'treated_days': 0, 'mortality': 2160, 'total_daly': 2, 'yld': 2592, 'yll': 2160, 'categorical_risk': 0, 'graded_sequela': 0, 'birth_prevalence': 108, 'live_births': 108, 'proportion': 2, 'distribution_mean': 2, 'distribution_std_dev': 2, 'prevalence': 0}
#
# Missing (0 data column(s) not captured in a category):
#  set()
#
# Repeated (0 data column(s) appearing in more than one category):
#  {}
#
# Empty categories (5 categories with no matching data columns):
#  ['run_time', 'treated_days', 'categorical_risk', 'graded_sequela', 'prevalence']

# %%
output5.columns('intervention')
# Out:
# ['fortification_intervention.scenario']

# %%
output3.column_categories()
# Out:
# ['input_draw',
#  'random_seed',
#  'location',
#  'intervention',
#  'run_time',
#  'diseases_at_end',
#  'transition_count',
#  'population',
#  'person_time',
#  'treated_days',
#  'mortality',
#  'total_daly',
#  'yld',
#  'yll',
#  'categorical_risk',
#  'graded_sequela',
#  'birth_prevalence',
#  'live_births',
#  'proportion',
#  'distribution_mean',
#  'distribution_std_dev',
#  'prevalence']

# %%
output3.columns('person_time')[-20:]
# Out:
# ['person_time_in_2023_among_male_in_age_group_post_neonatal_vitamin_a_cat2_anemia_severe',
#  'person_time_in_2023_among_female_in_age_group_post_neonatal_vitamin_a_cat2_anemia_severe',
#  'person_time_in_2023_among_male_in_age_group_1_to_4_vitamin_a_cat2_anemia_severe',
#  'person_time_in_2023_among_female_in_age_group_1_to_4_vitamin_a_cat2_anemia_severe',
#  'person_time_in_2024_among_male_in_age_group_early_neonatal_vitamin_a_cat2_anemia_severe',
#  'person_time_in_2024_among_female_in_age_group_early_neonatal_vitamin_a_cat2_anemia_severe',
#  'person_time_in_2024_among_male_in_age_group_late_neonatal_vitamin_a_cat2_anemia_severe',
#  'person_time_in_2024_among_female_in_age_group_late_neonatal_vitamin_a_cat2_anemia_severe',
#  'person_time_in_2024_among_male_in_age_group_post_neonatal_vitamin_a_cat2_anemia_severe',
#  'person_time_in_2024_among_female_in_age_group_post_neonatal_vitamin_a_cat2_anemia_severe',
# ...

# %%
output3.columns('graded_sequela')[:20]
# Out:
# ['susceptible_to_diarrheal_diseases_to_diarrheal_diseases_event_count_in_2020_among_male_in_age_group_early_neonatal_vitamin_a_cat1_anemia_mild',
#  'susceptible_to_diarrheal_diseases_to_diarrheal_diseases_event_count_in_2020_among_female_in_age_group_early_neonatal_vitamin_a_cat1_anemia_mild',
#  'susceptible_to_diarrheal_diseases_to_diarrheal_diseases_event_count_in_2020_among_male_in_age_group_late_neonatal_vitamin_a_cat1_anemia_mild',
#  'susceptible_to_diarrheal_diseases_to_diarrheal_diseases_event_count_in_2020_among_female_in_age_group_late_neonatal_vitamin_a_cat1_anemia_mild',
#  'susceptible_to_diarrheal_diseases_to_diarrheal_diseases_event_count_in_2020_among_male_in_age_group_post_neonatal_vitamin_a_cat1_anemia_mild',
#  'susceptible_to_diarrheal_diseases_to_diarrheal_diseases_event_count_in_2020_among_female_in_age_group_post_neonatal_vitamin_a_cat1_anemia_mild',
# ...

# %%
output3.columns('yld')[:20]
# Out:
# ['ylds_due_to_diarrheal_diseases_in_2020_among_female_in_age_group_early_neonatal_vitamin_a_cat1_anemia_none',
#  'ylds_due_to_vitamin_a_deficiency_in_2020_among_female_in_age_group_early_neonatal_vitamin_a_cat1_anemia_none',
#  'ylds_due_to_iron_deficiency_in_2020_among_female_in_age_group_early_neonatal_vitamin_a_cat1_anemia_none',
#  'ylds_due_to_diarrheal_diseases_in_2020_among_female_in_age_group_early_neonatal_vitamin_a_cat2_anemia_none',
#  'ylds_due_to_vitamin_a_deficiency_in_2020_among_female_in_age_group_early_neonatal_vitamin_a_cat2_anemia_none',
#  'ylds_due_to_iron_deficiency_in_2020_among_female_in_age_group_early_neonatal_vitamin_a_cat2_anemia_none',
#  'ylds_due_to_diarrheal_diseases_in_2021_among_female_in_age_group_early_neonatal_vitamin_a_cat1_anemia_none',
#  'ylds_due_to_vitamin_a_deficiency_in_2021_among_female_in_age_group_early_neonatal_vitamin_a_cat1_anemia_none',
# ...

# %%
raw_output3[
    'ylds_due_to_iron_deficiency_in_2021_among_male_in_age_group_late_neonatal_vitamin_a_cat2_anemia_none'
].head(20)
# Out:
# input_draw_number  random_seed
# 21.0               199.0          0.0
# 946.0              389.0          0.0
# 514.0              129.0          0.0
# 482.0              45.0           0.0
# 533.0              306.0          0.0
# 21.0               88.0           0.0
# 602.0              243.0          0.0
# 223.0              55.0           0.0
# 680.0              389.0          0.0
# 417.0              92.0           0.0
# 21.0               87.0           0.0
# 620.0              16.0           0.0
# 514.0              235.0          0.0
# 21.0               45.0           0.0
# 55.0               114.0          0.0
# 482.0              199.0          0.0
# 55.0               16.0           0.0
# 417.0              133.0          0.0
# 524.0              43.0           0.0
# 680.0              139.0          0.0
# Name: ylds_due_to_iron_deficiency_in_2021_among_male_in_age_group_late_neonatal_vitamin_a_cat2_anemia_none, dtype: float64

# %%
raw_output3.filter(regex=r'ylds_due_to_iron_deficiency\w+anemia_none').head()
# Out:
#                                ylds_due_to_iron_deficiency_in_2020_among_female_in_age_group_early_neonatal_vitamin_a_cat1_anemia_none  \
# input_draw_number random_seed
# 21.0              199.0                                                      0.0
# 946.0             389.0                                                      0.0
# 514.0             129.0                                                      0.0
# 482.0             45.0                                                       0.0
# 533.0             306.0                                                      0.0
#
#                                ylds_due_to_iron_deficiency_in_2020_among_female_in_age_group_early_neonatal_vitamin_a_cat2_anemia_none  \
# input_draw_number random_seed
# 21.0              199.0                                                      0.0
# 946.0             389.0                                                      0.0
# ...

# %%
raw_output3.filter(regex=r'ylds_due_to_iron_deficiency\w+anemia_none').head()
# Out:
#                                ylds_due_to_iron_deficiency_in_2020_among_female_in_age_group_early_neonatal_vitamin_a_cat1_anemia_none  \
# input_draw_number random_seed
# 21.0              199.0                                                      0.0
# 946.0             389.0                                                      0.0
# 514.0             129.0                                                      0.0
# 482.0             45.0                                                       0.0
# 533.0             306.0                                                      0.0
#
#                                ylds_due_to_iron_deficiency_in_2020_among_female_in_age_group_early_neonatal_vitamin_a_cat2_anemia_none  \
# input_draw_number random_seed
# 21.0              199.0                                                      0.0
# 946.0             389.0                                                      0.0
# ...

# %%
raw_output3.filter(regex=r'ylds_due_to_iron_deficiency\w+anemia_none').sum().sum()
# Out:
# 0.0

# %%
raw_output3.filter(regex=r'ylds_due_to_iron_deficiency\w+anemia_mild').head()
# Out:
#                                ylds_due_to_iron_deficiency_in_2020_among_male_in_age_group_early_neonatal_vitamin_a_cat1_anemia_mild  \
# input_draw_number random_seed
# 21.0              199.0                                                 0.008238
# 946.0             389.0                                                 0.003513
# 514.0             129.0                                                 0.003079
# 482.0             45.0                                                  0.007151
# 533.0             306.0                                                 0.003168
#
#                                ylds_due_to_iron_deficiency_in_2020_among_female_in_age_group_early_neonatal_vitamin_a_cat1_anemia_mild  \
# input_draw_number random_seed
# 21.0              199.0                                                 0.003868
# 946.0             389.0                                                 0.002633
# ...

# %%
raw_output3.filter(regex=r'ylds_due_to_iron_deficiency\w+anemia_mild').sum().head(10)
# Out:
# ylds_due_to_iron_deficiency_in_2020_among_male_in_age_group_early_neonatal_vitamin_a_cat1_anemia_mild         8.063977
# ylds_due_to_iron_deficiency_in_2020_among_female_in_age_group_early_neonatal_vitamin_a_cat1_anemia_mild       6.408526
# ylds_due_to_iron_deficiency_in_2020_among_male_in_age_group_late_neonatal_vitamin_a_cat1_anemia_mild         24.041877
# ylds_due_to_iron_deficiency_in_2020_among_female_in_age_group_late_neonatal_vitamin_a_cat1_anemia_mild       19.577922
# ylds_due_to_iron_deficiency_in_2020_among_male_in_age_group_post_neonatal_vitamin_a_cat1_anemia_mild        563.601326
# ylds_due_to_iron_deficiency_in_2020_among_female_in_age_group_post_neonatal_vitamin_a_cat1_anemia_mild      542.882427
# ylds_due_to_iron_deficiency_in_2020_among_male_in_age_group_1_to_4_vitamin_a_cat1_anemia_mild              1668.224336
# ylds_due_to_iron_deficiency_in_2020_among_female_in_age_group_1_to_4_vitamin_a_cat1_anemia_mild            1560.285603
# ...

# %%
raw_output3.filter(regex=r'ylds_due_to_vitamin_a_deficiency\w+anemia_none').head()
# Out:
#                                ylds_due_to_vitamin_a_deficiency_in_2020_among_female_in_age_group_early_neonatal_vitamin_a_cat1_anemia_none  \
# input_draw_number random_seed
# 21.0              199.0                                                 0.000000
# 946.0             389.0                                                 0.000000
# 514.0             129.0                                                 0.000572
# 482.0             45.0                                                  0.000690
# 533.0             306.0                                                 0.000000
#
#                                ylds_due_to_vitamin_a_deficiency_in_2020_among_female_in_age_group_early_neonatal_vitamin_a_cat2_anemia_none  \
# input_draw_number random_seed
# 21.0              199.0                                                      0.0
# 946.0             389.0                                                      0.0
# ...

# %%
raw_output3.filter(regex=r'ylds_due_to_vitamin_a_deficiency\w+anemia_none').sum().head(10)
# Out:
# ylds_due_to_vitamin_a_deficiency_in_2020_among_female_in_age_group_early_neonatal_vitamin_a_cat1_anemia_none    0.865097
# ylds_due_to_vitamin_a_deficiency_in_2020_among_female_in_age_group_early_neonatal_vitamin_a_cat2_anemia_none    0.199483
# ylds_due_to_vitamin_a_deficiency_in_2021_among_female_in_age_group_early_neonatal_vitamin_a_cat1_anemia_none    1.824926
# ylds_due_to_vitamin_a_deficiency_in_2021_among_female_in_age_group_early_neonatal_vitamin_a_cat2_anemia_none    0.412115
# ylds_due_to_vitamin_a_deficiency_in_2021_among_male_in_age_group_late_neonatal_vitamin_a_cat2_anemia_none       3.147578
# ylds_due_to_vitamin_a_deficiency_in_2022_among_female_in_age_group_early_neonatal_vitamin_a_cat1_anemia_none    1.783823
# ylds_due_to_vitamin_a_deficiency_in_2022_among_female_in_age_group_early_neonatal_vitamin_a_cat2_anemia_none    0.406844
# ylds_due_to_vitamin_a_deficiency_in_2022_among_male_in_age_group_late_neonatal_vitamin_a_cat2_anemia_none       3.214335
# ...

# %%
raw_output3.filter(regex=r'ylds_due_to_vitamin_a_deficiency\w+anemia_mild').sum().head(10)
# Out:
# ylds_due_to_vitamin_a_deficiency_in_2020_among_male_in_age_group_early_neonatal_vitamin_a_cat1_anemia_mild        58.095794
# ylds_due_to_vitamin_a_deficiency_in_2020_among_female_in_age_group_early_neonatal_vitamin_a_cat1_anemia_mild      41.593058
# ylds_due_to_vitamin_a_deficiency_in_2020_among_male_in_age_group_late_neonatal_vitamin_a_cat1_anemia_mild        167.172881
# ylds_due_to_vitamin_a_deficiency_in_2020_among_female_in_age_group_late_neonatal_vitamin_a_cat1_anemia_mild      119.189379
# ylds_due_to_vitamin_a_deficiency_in_2020_among_male_in_age_group_post_neonatal_vitamin_a_cat1_anemia_mild       2262.501245
# ylds_due_to_vitamin_a_deficiency_in_2020_among_female_in_age_group_post_neonatal_vitamin_a_cat1_anemia_mild     2391.739086
# ylds_due_to_vitamin_a_deficiency_in_2020_among_male_in_age_group_1_to_4_vitamin_a_cat1_anemia_mild              3145.982797
# ...

# %%
raw_output3.filter(regex=r'ylds_due_to_vitamin_a_deficiency\w+vitamin_a_cat2\w+anemia_none').head()
# Out:
#                                ylds_due_to_vitamin_a_deficiency_in_2020_among_female_in_age_group_early_neonatal_vitamin_a_cat2_anemia_none  \
# input_draw_number random_seed
# 21.0              199.0                                                      0.0
# 946.0             389.0                                                      0.0
# 514.0             129.0                                                      0.0
# 482.0             45.0                                                       0.0
# 533.0             306.0                                                      0.0
#
#                                ylds_due_to_vitamin_a_deficiency_in_2021_among_female_in_age_group_early_neonatal_vitamin_a_cat2_anemia_none  \
# input_draw_number random_seed
# 21.0              199.0                                                 0.000000
# 946.0             389.0                                                 0.000000
# ...

# %%
raw_output3.query('location == "Nigeria"').shape
# Out:
# (1000, 10069)

# %%
# raw_output3 = Raw output from model 3 for all locations
# Filter to one country:
country_output3 = raw_output3.query('location == "Nigeria"')
# Compute YLDs due to vitamin A deficiency for a particular group:
ylds_vad_1to4_vita_cat2_anemia_none = country_output3.filter(
    regex=r'ylds_due_to_vitamin_a_deficiency\w+1_to_4\w+vitamin_a_cat2\w+anemia_none')
ylds_vad_1to4_vita_cat2_anemia_none = ylds_vad_1to4_vita_cat2_anemia_none.groupby(
    level='input_draw_number').sum()
ylds_vad_1to4_vita_cat2_anemia_none.head()
# vitamin_a_cat2 should be no VAD, so why are there YLDs due to VAD?
# Out:
#                    ylds_due_to_vitamin_a_deficiency_in_2020_among_male_in_age_group_1_to_4_vitamin_a_cat2_anemia_none  \
# input_draw_number
# 21.0                                                      152.251676
# 29.0                                                      203.364693
# 55.0                                                       98.181772
# 78.0                                                      149.256473
# 155.0                                                     153.964022
#
#                    ylds_due_to_vitamin_a_deficiency_in_2020_among_female_in_age_group_1_to_4_vitamin_a_cat2_anemia_none  \
# input_draw_number
# 21.0                                                      138.145595
# 29.0                                                      159.216477
# 55.0                                                      208.218167
# 78.0                                                      200.973797
# 155.0                                                     116.013360
# ...

# %%
(vita_cat2_ylds_anemia_none > 0)#.any(axis=1)
# Out:
#                    ylds_due_to_vitamin_a_deficiency_in_2020_among_female_in_age_group_early_neonatal_vitamin_a_cat2_anemia_none  \
# input_draw_number
# 21.0                                                           False
# 29.0                                                           False
# 55.0                                                           False
# 78.0                                                           False
# 155.0                                                          False
# 223.0                                                          False
# 232.0                                                          False
# 254.0                                                          False
# 307.0                                                          False
# 357.0                                                          False
# 394.0                                                          False
# ...

# %%
# Raw output from model 3
vita_cat2_ylds_anemia_severe = raw_output3.filter(
    regex=r'ylds_due_to_vitamin_a_deficiency\w+vitamin_a_cat2\w+anemia_severe')
vita_cat2_ylds_anemia_severe = vita_cat2_ylds_anemia_severe.groupby(
    level='input_draw_number').sum()
vita_cat2_ylds_anemia_severe
# Out:
#                    ylds_due_to_vitamin_a_deficiency_in_2020_among_male_in_age_group_early_neonatal_vitamin_a_cat2_anemia_severe  \
# input_draw_number
# 21.0                                                        0.625712
# 29.0                                                        0.799839
# 55.0                                                        0.692253
# 78.0                                                        1.443313
# 155.0                                                       0.239969
# 223.0                                                       0.696949
# 232.0                                                       1.617570
# 254.0                                                       0.804918
# 307.0                                                       1.048097
# 357.0                                                       0.500922
# 394.0                                                       0.869453
# ...

# %%
raw_output5.filter(regex=r'ylds_due_to_vitamin_a_deficiency').head()
# Out:
#                                ylds_due_to_vitamin_a_deficiency_in_2020_among_male_in_age_group_early_neonatal_folic_acid_unknown_vitamin_a_covered  \
# input_draw_number random_seed
# 829.0             245.0                                                      0.0
# 155.0             92.0                                                       0.0
# 394.0             129.0                                                      0.0
# 533.0             134.0                                                      0.0
# 155.0             377.0                                                      0.0
#
#                                ylds_due_to_vitamin_a_deficiency_in_2020_among_female_in_age_group_early_neonatal_folic_acid_unknown_vitamin_a_covered  \
# input_draw_number random_seed
# 829.0             245.0                                                 0.000000
# 155.0             92.0                                                  0.000000
# ...

# %%
# Columns in model 5 with 'cat1' or 'cat2' in the name 
raw_output5.filter(regex=r'cat\d').columns
# Out:
# Index([], dtype='object')

# %%
# Columns in model 3 with 'cat1' or 'cat2' in the name 
raw_output3.filter(regex=r'cat\d').columns[:5]
# Out:
# Index(['susceptible_to_diarrheal_diseases_to_diarrheal_diseases_event_count_in_2020_among_male_in_age_group_early_neonatal_vitamin_a_cat1_anemia_none',
#        'susceptible_to_diarrheal_diseases_to_diarrheal_diseases_event_count_in_2020_among_female_in_age_group_early_neonatal_vitamin_a_cat1_anemia_none',
#        'susceptible_to_diarrheal_diseases_to_diarrheal_diseases_event_count_in_2020_among_male_in_age_group_late_neonatal_vitamin_a_cat1_anemia_none',
#        'susceptible_to_diarrheal_diseases_to_diarrheal_diseases_event_count_in_2020_among_female_in_age_group_late_neonatal_vitamin_a_cat1_anemia_none',
#        'susceptible_to_diarrheal_diseases_to_diarrheal_diseases_event_count_in_2020_among_male_in_age_group_post_neonatal_vitamin_a_cat1_anemia_none'],
#       dtype='object')

# %%
raw_output5.filter(regex=r'anemia').head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(829.0, 245.0), (155.0, 92.0), (394.0, 129.0), (533.0, 134.0), (155.0, 377.0)]
